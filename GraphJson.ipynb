# %%
# !pip install python-igraph jsonlines
# Out:
# Collecting python-igraph
#   Downloading https://files.pythonhosted.org/packages/8b/74/24a1afbf3abaf1d5f393b668192888d04091d1a6d106319661cd4af05406/python_igraph-0.8.2-cp36-cp36m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 2.7MB/s
# Collecting jsonlines
#   Downloading https://files.pythonhosted.org/packages/4f/9a/ab96291470e305504aa4b7a2e0ec132e930da89eb3ca7a82fbe03167c131/jsonlines-1.2.0-py2.py3-none-any.whl
# Collecting texttable>=1.6.2
#   Downloading https://files.pythonhosted.org/packages/ec/b1/8a1c659ce288bf771d5b1c7cae318ada466f73bd0e16df8d86f27a2a3ee7/texttable-1.6.2-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from jsonlines) (1.12.0)
# Installing collected packages: texttable, python-igraph, jsonlines
# Successfully installed jsonlines-1.2.0 python-igraph-0.8.2 texttable-1.6.2

# %%
import igraph
import jsonlines
import json
import numpy as np
from operator import itemgetter
from pandas import DataFrame
from linecache import getline
from subprocess import check_output
from collections import Counter

# %%
class Search():
  def __init__(self,search_file,user_file):

    self.search_details = search_file
    self.search_term_count = self.line_count(self.search_details) 
    self.search_terms = self._find_search_terms()

    self.user_details = user_file
    self.user_count = self.line_count(self.user_details)
    self.users = self._find_users()

    self.course_list = []
    self.course_list = self._find_courses()

    self.course_dict = {}
    self.course_dict = self._find_course_details('new_course_details.jsonl')
  
  def get_search_terms(self):
    return self.search_terms
  
  def get_users(self):
    return self.users

  def get_courses(self):
    return self.course_list

  def get_course_details(self):
    return self.course_dict
  
  def line_count(self,filename):
    return int(check_output(['wc', '-l', filename]).split()[0])

  def _find_course_details(self,course_details_file):
    with open(course_details_file) as file:
      for line in file:
        line = json.loads(line)
        self.course_dict[line['course_id']] = line['course_title']
    return self.course_dict

  def _find_courses(self):
    
    with open(self.search_details) as file:
      for line in file:
        line = json.loads(line)
        for course in line['course_clicked']:
          if course['course'] not in self.course_list:
            self.course_list.append(course['course'])
        for course in line['wishlist']:
          if course not in self.course_list:
            self.course_list.append(course)
        for course in line['enrollment']:
          if course not in self.course_list:
            self.course_list.append(course)
    return self.course_list

  def get_courses_of_user(self,user_id):
    user = int(np.where(self.users == user_id)[0]) + 1
    user_det = getline(self.user_details,user)
    user_det = json.loads(user_det)

    course_set = []

    if user_det['course_clicked']:
      for course in user_det['course_clicked']:
        if course['course'].strip(' ') not in course_set:
          course_set.append(course['course'].strip(' '))

    if user_det['course_enrollment']:
      for course in user_det['course_enrollment']:
        if course['course'].strip(' ') not in course_set:
          course_set.append(course['course'])

    if user_det['course_wishlist']:
      for c in user_det['course_wishlist']:
        if c.strip(' ') not in course_set:
          course_set.append(c.strip(' '))

    return course_set

  def _find_search_terms(self):
    search_terms = np.array([ '' for i in range(self.search_term_count)],dtype='object')
    i = 0
    with open(self.search_details) as file:
      for line in file:
        line = json.loads(line)
        search_terms[i] = line['search_term'][0]
        i+=1
    return search_terms
  
  def _find_users(self):
    users = np.array([ '' for i in range(self.user_count)],dtype='object')
    i = 0
    with open(self.user_details) as file:
      for line in file:
        line = json.loads(line)
        users[i] = line['user']
        i+=1
    return users

  def _calculate_similarity(self,clicks_x,clicks_y,wishlist_x,wishlist_y,enrollment_x,enrollment_y):
    def jaccard_similarity(product_list_1,product_list_2):
      s1 = set(product_list_1)
      s2 = set(product_list_2)
      if len(s1) == 0 or len(s2) == 0:
        return 0.0
      return float(len(s1.intersection(s2))/len(s1.union(s2)))

    return (jaccard_similarity(clicks_x,clicks_y) + jaccard_similarity(wishlist_x,wishlist_y) + jaccard_similarity(enrollment_x,enrollment_y))

  def get_edges(self):

    with open(self.search_details) as file_x:
      for line_x in file_x:
        query_x = json.loads(line_x)

        clicks_x = [ item_x['course'] for item_x in query_x['course_clicked'] ]
        wishlist_x = query_x['wishlist']
        enrollment_x = query_x['enrollment']

        with open(self.search_details) as file_y:
          for line_y in file_y:
            query_y = json.loads(line_y)

            clicks_y = [ item_y['course'] for item_y in query_y['course_clicked']]
            wishlist_y = query_y['wishlist']
            enrollment_y = query_y['enrollment']

            similarity = self._calculate_similarity(clicks_x,clicks_y,wishlist_x,wishlist_y,enrollment_x,enrollment_y)

            yield query_x['search_term'][0],query_y['search_term'][0],similarity

  def get_course_query_interest(self,course_id,query_term):

    line_no = int(np.where(self.search_terms == query_term)[0]) + 1
    query_line = getline(self.search_details,line_no)
    query_line = json.loads(query_line)

    clicks,clicks_sum = 0,0
    wish,wishlist_sum = 0,len(query_line['wishlist']) if query_line['wishlist'] else 0 
    enroll,enrollment_sum = 0,len(query_line['enrollment']) if query_line['enrollment'] else 0

    if query_line['course_clicked']:
      for course in query_line['course_clicked']:
        if course['course'] == course_id:
          clicks = course['count']
        clicks_sum += course['count']
    
    if query_line['wishlist']:
      if course_id in query_line['wishlist']:
        wish = 1
    
    if query_line['enrollment']:
      if course_id in query_line['enrollment']:
        enroll = 1

    a,b,c = 0,0,0

    if clicks_sum>0:
      a = clicks/clicks_sum

    if wishlist_sum > 0:
      b = wish/wishlist_sum

    if enrollment_sum > 0:
      c = enroll/enrollment_sum

    return a + b + c

  def get_course_user_interest(self,user_id,course_id):
    line_no = int(np.where(self.users == user_id)[0]) + 1
    query_line = getline(self.user_details,line_no)
    query_line = json.loads(query_line)

    clicks,clicks_sum = 0,0
    wish,wishlist_sum = 0,len(query_line['course_wishlist']) if query_line['course_wishlist'] else 0
    enroll,enrollment_sum = 0,len(query_line['course_enrollment']) if query_line['course_enrollment'] else 0

    if query_line['course_clicked']:
      for course in query_line['course_clicked']:
        if course['course'].strip(' ') == course_id:
          clicks = course['count']
        clicks_sum += course['count']

    if query_line['course_wishlist']:
      if course_id in query_line['course_wishlist']:
        wish = 1
    
    if query_line['course_enrollment']:
      for course in query_line['course_enrollment']:
        if course['course'].strip(' ') == course_id:
          enroll = 1
          break

    a,b,c = 0,0,0

    if clicks_sum>0:
      a = clicks/clicks_sum

    if wishlist_sum > 0:
      b = wish/wishlist_sum

    if enrollment_sum > 0:
      c = enroll/enrollment_sum

    return a + b + c

  def most_common_search(self,final_user_set):
    self.user_courses_map = {}
    for user in self.users:

      similar_users = final_user_set.get(user,[])
      similar_users_course_set = []
      final_course_set = []
      if not similar_users:
        continue
      for similar_user in similar_users:

        if user != similar_user:
          line_count = int(np.where(self.users == similar_user)[0]) + 1

          line = getline(self.user_details,line_count)
          line = json.loads(line)

          if line['course_clicked']:
            for course in line['course_clicked']:
              similar_users_course_set.append(course['course'])

          if line['course_enrollment']:
            for course in line['course_enrollment']:
              similar_users_course_set.append(course['course'])

          if line['course_wishlist']:
            for course in line['course_wishlist']:
              similar_users_course_set.append(course)

      course_subset = Counter(similar_users_course_set)
      for key,value in course_subset.items():
        if value>=4:
          final_course_set.append(key)
      self.user_courses_map[user] = final_course_set
    return self.user_courses_map

# %%
class SearchQueryGraph(object):

    """
      SearchQueryGraph contains methods for implementing the knowledge graph of search terms using the course clicks on a
      search term as historical data required for calculating the various metrics according to the research paper 
      Using Probabilistic Tag Modeling to Improve Recommendations Gokkaya et al August 2017 
      (http://ml4ed.cc/attachments/GokkayaUsing.pdf)
    """
    def __init__(self,query_list):

      self.tag_list=[] # List of Tags required for creating knowledge graph
      self.num_of_clusters = 0 
      self.query_list = query_list
      self.tag_search_query_map = {}
      self.graph = igraph.Graph(n=len(self.query_list),directed=True,vertex_attrs={'name':query_list},edge_attrs={'weight':[]})
      
      
    def create_graph(self, edge_list):
      """
        The data arguement takes two-tiered list with each inner list being of the form (node1,node2,weight).
        The _create_graph method creates a graph using igraph library and loads it into the object variable self.graph
      """
      # print(edge_list)
      self.graph.add_edge(edge_list[0],edge_list[1])
      # edges = self.graph.es['weight']
      # edges.extend(edgeweight)
      # print(edges)
      # self.graph.es['weight'] = x
      
    def add_weights(self,edgeweight):
      self.graph.es['weight'] = edgeweight    
        
    def create_clusters(self):
      """
        The _create_clusters method applies the walktrap graph community detection algorithm on the weighted graph 
        of the variable self.graph and creates the clusters obtained from the walktrap algritm on the object attribute 
        self.clusters
      """
      self.tag_list=[]  
      self.graph.layout_fruchterman_reingold()
      self.dendogram = self.graph.community_walktrap(weights=self.graph.es["weight"], steps = 1)
      self.num_of_clusters = self.dendogram.optimal_count
      self.clusters= self.dendogram.as_clustering()

    def _get_subgraph(self,cluster_id):
      """
        Returns subgraphs from the original graph according to the provided cluster_id
      """
      return self.clusters.subgraph(cluster_id)

    def _get_subgraphs(self):
      """
        Yields each subgraph of the graph containing a cluster one-by-one on each of the function call
      """
      for cluster_id in range(self.num_of_clusters):
        yield self.clusters.subgraph(cluster_id)

    def _get_tag_subgraph(self,subgraph,scores=False):
      """
        Returns the tag assigned to the given subgraph according to pagerank algorithm if scores arguement is set to false if set to False.
        
        Returns the tag assisgned to the given subgraph and the pagerank score for each node in the subgraph in the 
        format (node,score) if the scores arguement is set to True
      """
      #Applies pagerank algorithm on the given subgraph.
      pagerank_score = subgraph.pagerank()

      #Finds the tag with the maximum pagerank score in the given subgraph.
      tag_index = pagerank_score.index(max(pagerank_score))
      tag = subgraph.vs[tag_index]["name"]
      if(scores == False):
        return tag

      # Find the pagerank score of each node in the subgraph and assigned to cluster_score
      cluster_score=[]
      for index,node in enumerate(subgraph.vs):
        cluster_score.append([subgraph.vs[index]['name'],pagerank_score[index]])
      return tag, cluster_score

    def get_tags(self,scores=False):
      """
        Yields the tag assigned to each subgraph in the graph if scores is set to False.

        Yields the tag assigned to each subgraph and the pagerank score of each node in the subgraph if scores is set 
        to True
      """
      for subgraph in self._get_subgraphs():
        self.tag_search_query_map[self._get_tag_subgraph(subgraph)] = [item['name'] for item in subgraph.vs]
        yield self._get_tag_subgraph(subgraph,scores)

    def get_tag_list(self):

      """
        Returns list of tags assigned to each subgraph in the graph according to the pagerank score of each cluster
      """
      if not self.tag_list:
        for cluster_id in range(self.num_of_clusters):
          tag = self._get_tag_subgraph(self._get_subgraph(cluster_id))
          self.tag_list.append(tag)
      return self.tag_list

    def because_you_searched(self,search_term,course_tag_profile):
      out_list = []
      for tag,search_query_list in self.tag_search_query_map.items():
        if search_term not in search_query_list:
          continue
        else:
          course_tag_profile = course_tag_profile.sort_values(by=tag,axis=0,ascending=False)
          return course_tag_profile.index[course_tag_profile[tag]>0].tolist()

# %%
search_handler = Search('datasearchcomb.jsonl','datausercomblast.jsonl')
graph_handler = SearchQueryGraph(search_handler.get_search_terms())

# %%
# weights_arr = np.array([ 0 for i in range(search_handler.search_term_count**2) ],dtype='float')
w = []
count = search_handler.search_term_count**2
j=0
for i in search_handler.get_edges():
  if i[2] <0.2:
    continue
  graph_handler.create_graph(i[:2])
  w.append(i[2])
graph_handler.add_weights(w)

# %%
courses = search_handler.get_courses()
users = search_handler.get_users()
search_terms = search_handler.get_search_terms()
course_details = search_handler.get_course_details()
print(courses)
print(search_terms)
# Out:
# ['608158782373810000420', '559158644019010000287', '757158798294310000420', '245156760451710000000', '261156788006210000000', '233158547303310000367', '748158780599110000419', '374158781517410000359', '16157907994810000048', '367158754185010000419', '170156784201510000081', '442158763935310000420', '777158696144210000417', '322157599163910000013', '22156405498210000048', '447158697470210000419', '470158701696410000420', '393158755559210000419', '838158696198810000419', '919158696284310000418', '280158237795110000289', '385156872993410000218', '234158410337210000287', '250158739892410000390', '759158666877610000390', '157158730481210000390', '585158780493310000390', '457158782807710000390', '949158609709610000390', '737158711625710000419', '705158582903510000302', '448157659010110000302', '515156638953610000000', '20158782281010000419', '494157805645010000294', '254158738215210000294', '162157622551210000289', '250158496964910000368', '118158497268010000368', '279157572608010000289', '257156994522510000218', '152158832503910000406']
# ['the complete sql bootcamp 2020' 'sql' 'complete design thinking'
#  'bigdata' 'vfx' 'learn flutter from scratch' 'online yoga' 'the art'
#  'html' 'robotic process automation' 'soft skills' 'digital marketing'
#  'finance' 'social' 'java' 'angular - the complete guide'
#  'automation anywhere' 'mayuresh' 'python for beginners' 'deep learning'
#  'learn basic calligraphy' 'flutter' 'sql server administration part1'
#  'kileshwar' 'photoshop cc 2020' 'angular js' 'ios 13' 'robotics' 'auto'
#  'complete guitar system' 'graphic design masterclass' 'data structure'
#  'swapna' 'mathematics' 'math' 'c' 'learn' 'cyber security']

# %%
graph_handler.create_clusters()
tags = graph_handler.get_tag_list()

# %%
tags
# Out:
# ['the complete sql bootcamp 2020',
#  'bigdata',
#  'automation anywhere',
#  'learn',
#  'online yoga',
#  'the art',
#  'html',
#  'robotic process automation',
#  'soft skills',
#  'digital marketing',
#  'social',
#  'mayuresh',
#  'sql server administration part1',
#  'kileshwar',
#  'ios 13',
#  'robotics',
#  'data structure',
#  'cyber security']

# %%
print(graph_handler.clusters)
# Out:
# Clustering with 38 elements and 18 clusters
# [ 0] the complete sql bootcamp 2020, sql, complete design thinking
# [ 1] bigdata, swapna
# [ 2] vfx, finance, java, angular - the complete guide, automation anywhere,
#      flutter, photoshop cc 2020, angular js, auto, complete guitar system,
#      graphic design masterclass, mathematics, math, c
# [ 3] learn flutter from scratch, learn basic calligraphy, learn
# [ 4] online yoga
# [ 5] the art
# [ 6] html
# [ 7] robotic process automation
# [ 8] soft skills
# [ 9] digital marketing
# [10] social
# [11] mayuresh, python for beginners, deep learning
# [12] sql server administration part1
# [13] kileshwar
# [14] ios 13
# [15] robotics
# [16] data structure
# [17] cyber security

# %%
course_tag_profile = DataFrame(index = courses,columns = tags)
for c in courses:
    #Lists of the probability of each cluster tag being assigned to each course
  print("*********************************************************")
  print("COURSE",c)
  for tag,querylist in graph_handler.get_tags(scores=True):
    prob = 0

    for query,score in querylist:    
        prob = prob + (search_handler.get_course_query_interest(c,query)*score)
    
    course_tag_profile[tag][c] = prob
    if(prob>0):
      print("TAG",tag,prob)
# Out:
# *********************************************************
# COURSE 608158782373810000420
# TAG the complete sql bootcamp 2020 0.4444444444444444
# *********************************************************
# COURSE 559158644019010000287
# TAG the complete sql bootcamp 2020 0.08333333333333333
# *********************************************************
# COURSE 757158798294310000420
# TAG the complete sql bootcamp 2020 0.25
# TAG automation anywhere 0.07651186916458168
# *********************************************************
# COURSE 245156760451710000000
# TAG the complete sql bootcamp 2020 0.1111111111111111
# *********************************************************
# COURSE 261156788006210000000
# TAG the complete sql bootcamp 2020 0.1111111111111111
# TAG sql server administration part1 1.0
# *********************************************************
# COURSE 233158547303310000367
# TAG bigdata 0.6666666666666666
# *********************************************************
# COURSE 748158780599110000419
# TAG automation anywhere 0.15302373832916333
# *********************************************************
# COURSE 374158781517410000359
# TAG automation anywhere 1.0955798295396755
# TAG learn 0.42700729927007297
# *********************************************************
# COURSE 16157907994810000048
# TAG learn 0.024330900243309
# *********************************************************
# COURSE 367158754185010000419
# TAG learn 0.048661800486618
# *********************************************************
# COURSE 170156784201510000081
# TAG online yoga 2.0
# *********************************************************
# COURSE 442158763935310000420
# TAG the art 1.0
# *********************************************************
# COURSE 777158696144210000417
# TAG html 1.0
# *********************************************************
# COURSE 322157599163910000013
# TAG robotic process automation 1.0
# *********************************************************
# COURSE 22156405498210000048
# TAG soft skills 1.0
# *********************************************************
# COURSE 447158697470210000419
# TAG digital marketing 1.0
# *********************************************************
# COURSE 470158701696410000420
# TAG social 1.0
# *********************************************************
# COURSE 393158755559210000419
# TAG automation anywhere 0.07651186916458166
# *********************************************************
# COURSE 838158696198810000419
# TAG automation anywhere 0.07651186916458166
# *********************************************************
# COURSE 919158696284310000418
# TAG automation anywhere 0.11744065417709162
# *********************************************************
# COURSE 280158237795110000289
# TAG mayuresh 0.8333333333333333
# *********************************************************
# COURSE 385156872993410000218
# TAG mayuresh 0.16666666666666666
# *********************************************************
# COURSE 234158410337210000287
# TAG learn 0.49999999999999994
# *********************************************************
# COURSE 250158739892410000390
# TAG kileshwar 0.16666666666666666
# *********************************************************
# COURSE 759158666877610000390
# TAG kileshwar 0.16666666666666666
# *********************************************************
# COURSE 157158730481210000390
# TAG kileshwar 0.16666666666666666
# *********************************************************
# COURSE 585158780493310000390
# TAG kileshwar 0.16666666666666666
# *********************************************************
# COURSE 457158782807710000390
# TAG kileshwar 0.16666666666666666
# *********************************************************
# COURSE 949158609709610000390
# TAG kileshwar 0.16666666666666666
# *********************************************************
# COURSE 737158711625710000419
# TAG automation anywhere 0.07651186916458168
# *********************************************************
# COURSE 705158582903510000302
# TAG automation anywhere 0.07651186916458168
# *********************************************************
# COURSE 448157659010110000302
# TAG ios 13 1.0
# *********************************************************
# COURSE 515156638953610000000
# TAG robotics 1.0
# *********************************************************
# COURSE 20158782281010000419
# TAG automation anywhere 0.07651186916458166
# *********************************************************
# COURSE 494157805645010000294
# TAG data structure 0.3333333333333333
# *********************************************************
# COURSE 254158738215210000294
# TAG data structure 0.3333333333333333
# *********************************************************
# COURSE 162157622551210000289
# TAG data structure 0.3333333333333333
# *********************************************************
# COURSE 250158496964910000368
# TAG bigdata 0.16666666666666666
# *********************************************************
# COURSE 118158497268010000368
# TAG bigdata 0.16666666666666666
# *********************************************************
# COURSE 279157572608010000289
# TAG automation anywhere 0.1461626085718354
# *********************************************************
# COURSE 257156994522510000218
# TAG automation anywhere 0.07651186916458166
# *********************************************************
# COURSE 152158832503910000406
# TAG cyber security 1.0

# %%
import numpy as np
for c1 in courses:
  # Recomendation system for finding out the courses similar to a given course by finding out the inner product of 
  # courses 
  print("****************************************************")
  print("COURSE:c1",c1,course_details[c1])
  for c2 in courses:
    if np.sum(np.inner(np.array(course_tag_profile.loc[c1,:]),np.array(course_tag_profile.loc[c2,:])))>0:
      print("SIMILAR COURSES", c2,course_details[c2])
  print('\n')
# Out:
# ****************************************************
# COURSE:c1 608158782373810000420 The Complete SQL Bootcamp 2020
# SIMILAR COURSES 608158782373810000420 The Complete SQL Bootcamp 2020
# SIMILAR COURSES 559158644019010000287 Requirements Gathering Techniques for a Software Development (Copy0)
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 245156760451710000000 MySQL
# SIMILAR COURSES 261156788006210000000 SQL Server Administration Part1
#
#
# ****************************************************
# COURSE:c1 559158644019010000287 Requirements Gathering Techniques for a Software Development (Copy0)
# SIMILAR COURSES 608158782373810000420 The Complete SQL Bootcamp 2020
# SIMILAR COURSES 559158644019010000287 Requirements Gathering Techniques for a Software Development (Copy0)
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 245156760451710000000 MySQL
# SIMILAR COURSES 261156788006210000000 SQL Server Administration Part1
#
#
# ****************************************************
# COURSE:c1 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 608158782373810000420 The Complete SQL Bootcamp 2020
# SIMILAR COURSES 559158644019010000287 Requirements Gathering Techniques for a Software Development (Copy0)
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 245156760451710000000 MySQL
# SIMILAR COURSES 261156788006210000000 SQL Server Administration Part1
# SIMILAR COURSES 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 393158755559210000419 Java
# SIMILAR COURSES 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 705158582903510000302 angulat js
# SIMILAR COURSES 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 257156994522510000218 Monthly meetings@CQA
#
#
# ****************************************************
# COURSE:c1 245156760451710000000 MySQL
# SIMILAR COURSES 608158782373810000420 The Complete SQL Bootcamp 2020
# SIMILAR COURSES 559158644019010000287 Requirements Gathering Techniques for a Software Development (Copy0)
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 245156760451710000000 MySQL
# SIMILAR COURSES 261156788006210000000 SQL Server Administration Part1
#
#
# ****************************************************
# COURSE:c1 261156788006210000000 SQL Server Administration Part1
# SIMILAR COURSES 608158782373810000420 The Complete SQL Bootcamp 2020
# SIMILAR COURSES 559158644019010000287 Requirements Gathering Techniques for a Software Development (Copy0)
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 245156760451710000000 MySQL
# SIMILAR COURSES 261156788006210000000 SQL Server Administration Part1
#
#
# ****************************************************
# COURSE:c1 233158547303310000367 BIGDATA
# SIMILAR COURSES 233158547303310000367 BIGDATA
# SIMILAR COURSES 250158496964910000368 tableau
# SIMILAR COURSES 118158497268010000368 Cloud computing
#
#
# ****************************************************
# COURSE:c1 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 393158755559210000419 Java
# SIMILAR COURSES 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 705158582903510000302 angulat js
# SIMILAR COURSES 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 257156994522510000218 Monthly meetings@CQA
#
#
# ****************************************************
# COURSE:c1 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 16157907994810000048 Machine Learning (Copy0)
# SIMILAR COURSES 367158754185010000419 Learn To Play The Drums
# SIMILAR COURSES 393158755559210000419 Java
# SIMILAR COURSES 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 234158410337210000287 LEARN BASIC CALLIGRAPHY
# SIMILAR COURSES 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 705158582903510000302 angulat js
# SIMILAR COURSES 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 257156994522510000218 Monthly meetings@CQA
#
#
# ****************************************************
# COURSE:c1 16157907994810000048 Machine Learning (Copy0)
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 16157907994810000048 Machine Learning (Copy0)
# SIMILAR COURSES 367158754185010000419 Learn To Play The Drums
# SIMILAR COURSES 234158410337210000287 LEARN BASIC CALLIGRAPHY
#
#
# ****************************************************
# COURSE:c1 367158754185010000419 Learn To Play The Drums
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 16157907994810000048 Machine Learning (Copy0)
# SIMILAR COURSES 367158754185010000419 Learn To Play The Drums
# SIMILAR COURSES 234158410337210000287 LEARN BASIC CALLIGRAPHY
#
#
# ****************************************************
# COURSE:c1 170156784201510000081 Online Yoga
# SIMILAR COURSES 170156784201510000081 Online Yoga
#
#
# ****************************************************
# COURSE:c1 442158763935310000420 The Art &amp; Science of Drawing
# SIMILAR COURSES 442158763935310000420 The Art &amp; Science of Drawing
#
#
# ****************************************************
# COURSE:c1 777158696144210000417 Web Designing with HTML, CSS &amp; Bootstrap
# SIMILAR COURSES 777158696144210000417 Web Designing with HTML, CSS &amp; Bootstrap
#
#
# ****************************************************
# COURSE:c1 322157599163910000013 Robotic Process Automation
# SIMILAR COURSES 322157599163910000013 Robotic Process Automation
#
#
# ****************************************************
# COURSE:c1 22156405498210000048 Soft Skills
# SIMILAR COURSES 22156405498210000048 Soft Skills
#
#
# ****************************************************
# COURSE:c1 447158697470210000419 Digital Marketing
# SIMILAR COURSES 447158697470210000419 Digital Marketing
#
#
# ****************************************************
# COURSE:c1 470158701696410000420 Learn Social Psychology
# SIMILAR COURSES 470158701696410000420 Learn Social Psychology
#
#
# ****************************************************
# COURSE:c1 393158755559210000419 Java
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 393158755559210000419 Java
# SIMILAR COURSES 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 705158582903510000302 angulat js
# SIMILAR COURSES 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 257156994522510000218 Monthly meetings@CQA
#
#
# ****************************************************
# COURSE:c1 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 393158755559210000419 Java
# SIMILAR COURSES 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 705158582903510000302 angulat js
# SIMILAR COURSES 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 257156994522510000218 Monthly meetings@CQA
#
#
# ****************************************************
# COURSE:c1 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 393158755559210000419 Java
# SIMILAR COURSES 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 705158582903510000302 angulat js
# SIMILAR COURSES 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 257156994522510000218 Monthly meetings@CQA
#
#
# ****************************************************
# COURSE:c1 280158237795110000289 Data Visualization in Python for Machine Learning Engineers
# SIMILAR COURSES 280158237795110000289 Data Visualization in Python for Machine Learning Engineers
# SIMILAR COURSES 385156872993410000218 Basics of Machine learning
#
#
# ****************************************************
# COURSE:c1 385156872993410000218 Basics of Machine learning
# SIMILAR COURSES 280158237795110000289 Data Visualization in Python for Machine Learning Engineers
# SIMILAR COURSES 385156872993410000218 Basics of Machine learning
#
#
# ****************************************************
# COURSE:c1 234158410337210000287 LEARN BASIC CALLIGRAPHY
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 16157907994810000048 Machine Learning (Copy0)
# SIMILAR COURSES 367158754185010000419 Learn To Play The Drums
# SIMILAR COURSES 234158410337210000287 LEARN BASIC CALLIGRAPHY
#
#
# ****************************************************
# COURSE:c1 250158739892410000390 Web Designing for Beginners 2.0
# SIMILAR COURSES 250158739892410000390 Web Designing for Beginners 2.0
# SIMILAR COURSES 759158666877610000390 Interior Designs
# SIMILAR COURSES 157158730481210000390 Interior Designs (Copy0)
# SIMILAR COURSES 585158780493310000390 HTML CSS
# SIMILAR COURSES 457158782807710000390 Solar Energy
# SIMILAR COURSES 949158609709610000390 Web Designing for Beginners
#
#
# ****************************************************
# COURSE:c1 759158666877610000390 Interior Designs
# SIMILAR COURSES 250158739892410000390 Web Designing for Beginners 2.0
# SIMILAR COURSES 759158666877610000390 Interior Designs
# SIMILAR COURSES 157158730481210000390 Interior Designs (Copy0)
# SIMILAR COURSES 585158780493310000390 HTML CSS
# SIMILAR COURSES 457158782807710000390 Solar Energy
# SIMILAR COURSES 949158609709610000390 Web Designing for Beginners
#
#
# ****************************************************
# COURSE:c1 157158730481210000390 Interior Designs (Copy0)
# SIMILAR COURSES 250158739892410000390 Web Designing for Beginners 2.0
# SIMILAR COURSES 759158666877610000390 Interior Designs
# SIMILAR COURSES 157158730481210000390 Interior Designs (Copy0)
# SIMILAR COURSES 585158780493310000390 HTML CSS
# SIMILAR COURSES 457158782807710000390 Solar Energy
# SIMILAR COURSES 949158609709610000390 Web Designing for Beginners
#
#
# ****************************************************
# COURSE:c1 585158780493310000390 HTML CSS
# SIMILAR COURSES 250158739892410000390 Web Designing for Beginners 2.0
# SIMILAR COURSES 759158666877610000390 Interior Designs
# SIMILAR COURSES 157158730481210000390 Interior Designs (Copy0)
# SIMILAR COURSES 585158780493310000390 HTML CSS
# SIMILAR COURSES 457158782807710000390 Solar Energy
# SIMILAR COURSES 949158609709610000390 Web Designing for Beginners
#
#
# ****************************************************
# COURSE:c1 457158782807710000390 Solar Energy
# SIMILAR COURSES 250158739892410000390 Web Designing for Beginners 2.0
# SIMILAR COURSES 759158666877610000390 Interior Designs
# SIMILAR COURSES 157158730481210000390 Interior Designs (Copy0)
# SIMILAR COURSES 585158780493310000390 HTML CSS
# SIMILAR COURSES 457158782807710000390 Solar Energy
# SIMILAR COURSES 949158609709610000390 Web Designing for Beginners
#
#
# ****************************************************
# COURSE:c1 949158609709610000390 Web Designing for Beginners
# SIMILAR COURSES 250158739892410000390 Web Designing for Beginners 2.0
# SIMILAR COURSES 759158666877610000390 Interior Designs
# SIMILAR COURSES 157158730481210000390 Interior Designs (Copy0)
# SIMILAR COURSES 585158780493310000390 HTML CSS
# SIMILAR COURSES 457158782807710000390 Solar Energy
# SIMILAR COURSES 949158609709610000390 Web Designing for Beginners
#
#
# ****************************************************
# COURSE:c1 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 393158755559210000419 Java
# SIMILAR COURSES 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 705158582903510000302 angulat js
# SIMILAR COURSES 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 257156994522510000218 Monthly meetings@CQA
#
#
# ****************************************************
# COURSE:c1 705158582903510000302 angulat js
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 393158755559210000419 Java
# SIMILAR COURSES 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 705158582903510000302 angulat js
# SIMILAR COURSES 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 257156994522510000218 Monthly meetings@CQA
#
#
# ****************************************************
# COURSE:c1 448157659010110000302 iOS 13 &amp; swift 5
# SIMILAR COURSES 448157659010110000302 iOS 13 &amp; swift 5
#
#
# ****************************************************
# COURSE:c1 515156638953610000000 Robotics
# SIMILAR COURSES 515156638953610000000 Robotics
#
#
# ****************************************************
# COURSE:c1 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 393158755559210000419 Java
# SIMILAR COURSES 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 705158582903510000302 angulat js
# SIMILAR COURSES 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 257156994522510000218 Monthly meetings@CQA
#
#
# ****************************************************
# COURSE:c1 494157805645010000294 Advanced Data Structures
# SIMILAR COURSES 494157805645010000294 Advanced Data Structures
# SIMILAR COURSES 254158738215210000294 Advanced Data Structures (Copy0)
# SIMILAR COURSES 162157622551210000289 Python for Data Science
#
#
# ****************************************************
# COURSE:c1 254158738215210000294 Advanced Data Structures (Copy0)
# SIMILAR COURSES 494157805645010000294 Advanced Data Structures
# SIMILAR COURSES 254158738215210000294 Advanced Data Structures (Copy0)
# SIMILAR COURSES 162157622551210000289 Python for Data Science
#
#
# ****************************************************
# COURSE:c1 162157622551210000289 Python for Data Science
# SIMILAR COURSES 494157805645010000294 Advanced Data Structures
# SIMILAR COURSES 254158738215210000294 Advanced Data Structures (Copy0)
# SIMILAR COURSES 162157622551210000289 Python for Data Science
#
#
# ****************************************************
# COURSE:c1 250158496964910000368 tableau
# SIMILAR COURSES 233158547303310000367 BIGDATA
# SIMILAR COURSES 250158496964910000368 tableau
# SIMILAR COURSES 118158497268010000368 Cloud computing
#
#
# ****************************************************
# COURSE:c1 118158497268010000368 Cloud computing
# SIMILAR COURSES 233158547303310000367 BIGDATA
# SIMILAR COURSES 250158496964910000368 tableau
# SIMILAR COURSES 118158497268010000368 Cloud computing
#
#
# ****************************************************
# COURSE:c1 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 393158755559210000419 Java
# SIMILAR COURSES 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 705158582903510000302 angulat js
# SIMILAR COURSES 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 257156994522510000218 Monthly meetings@CQA
#
#
# ****************************************************
# COURSE:c1 257156994522510000218 Monthly meetings@CQA
# SIMILAR COURSES 757158798294310000420 The Complete Personal Finance Course
# SIMILAR COURSES 748158780599110000419 VFX: Complete Houdini Bootcamp
# SIMILAR COURSES 374158781517410000359 Learn flutter from scratch
# SIMILAR COURSES 393158755559210000419 Java
# SIMILAR COURSES 838158696198810000419 Angular - The Complete Guide
# SIMILAR COURSES 919158696284310000418 AUTOMATION ANYWHERE
# SIMILAR COURSES 737158711625710000419 Photoshop CC 2020
# SIMILAR COURSES 705158582903510000302 angulat js
# SIMILAR COURSES 20158782281010000419 Graphic Design Masterclass
# SIMILAR COURSES 279157572608010000289 Mathematics from Scratch
# SIMILAR COURSES 257156994522510000218 Monthly meetings@CQA
#
#
# ****************************************************
# COURSE:c1 152158832503910000406 Cyber Security
# SIMILAR COURSES 152158832503910000406 Cyber Security

# %%
tag_user_structure = {}
user_tag_structure = {}
user_tag_profile = DataFrame(index = users,columns=tags)
for index,u in enumerate(users):
  print("*************************************************************")
  print("User",u,index)
  for tag,query_list in graph_handler.get_tags(scores=True):
    # print("Tag",tag)
    # print(query_list)
    prob_UT = []

    # Probablity of course being assigned a particular tag
    course_set = search_handler.get_courses_of_user(u)
    for c in course_set:
      # print(c)
      #Calculate the percentage of a user attention to the course
      prob_UC = search_handler.get_course_user_interest(u,c)
      # print(prob_UC)
      # Calculate the probabilty of the course being clicked after a search term
      prob = 0
      for query,score in query_list:
          w = search_handler.get_course_query_interest(c,query)
          prob = prob + (w*score)

      # print(prob)
      # Computing the probabilty of user being assigned the tag as sum of the above calculated values 
      prob_UTi = prob_UC * prob
      # print("P(C|T)",prob)
      if(prob_UTi>0):
          # print("P(U|T) for ",c, "course is = ",prob_UTi)
          prob_UT.append(prob_UTi)
    if(sum(prob_UT)):
      #Saving tag user structure
      user_arr = tag_user_structure.get(tag,[])
      user_arr.append(u)
      tag_user_structure[tag] = user_arr

      #Saving user tag structure
      tag_arr = user_tag_structure.get(u,[])
      tag_arr.append(tag)
      user_tag_structure[u] = tag_arr
      print("Tag",tag)
      print("P(U|T)=",sum(prob_UT))
      print('\n')
    x = sum(prob_UT)
    # print(x)
    user_tag_profile[tag][u] = x
# Out:
# *************************************************************
# User 10000372 0
# *************************************************************
# User 10000386 1
# *************************************************************
# User 10000391 2
# *************************************************************
# User 10000282 3
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.003584229390681003
#
#
# Tag automation anywhere
# P(U|T)= 0.07688477892002714
#
#
# Tag learn
# P(U|T)= 0.0689363964720964
#
#
# Tag soft skills
# P(U|T)= 0.03225806451612903
#
#
# Tag mayuresh
# P(U|T)= 0.00980392156862745
#
#
# Tag kileshwar
# P(U|T)= 0.005376344086021505
#
#
# Tag ios 13
# P(U|T)= 0.027777777777777776
#
#
# Tag robotics
# P(U|T)= 0.09108159392789374
#
#
# Tag data structure
# P(U|T)= 0.009259259259259259
#
#
# *************************************************************
# User 10000299 4
# Tag automation anywhere
# P(U|T)= 0.006994396066327421
#
#
# Tag ios 13
# P(U|T)= 0.014492753623188406
#
#
# Tag robotics
# P(U|T)= 0.09141583054626533
#
#
# Tag cyber security
# P(U|T)= 0.014492753623188406
#
#
# *************************************************************
# User 10000416 5
# Tag bigdata
# P(U|T)= 0.008438818565400843
#
#
# Tag automation anywhere
# P(U|T)= 0.20143571091981105
#
#
# Tag learn
# P(U|T)= 0.07700267947888755
#
#
# Tag robotic process automation
# P(U|T)= 0.012658227848101266
#
#
# Tag kileshwar
# P(U|T)= 0.01347866854195968
#
#
# Tag robotics
# P(U|T)= 0.012658227848101266
#
#
# Tag data structure
# P(U|T)= 0.004219409282700422
#
#
# Tag cyber security
# P(U|T)= 0.06821378340365682
#
#
# *************************************************************
# User 10000422 6
# Tag bigdata
# P(U|T)= 0.020833333333333332
#
#
# Tag robotic process automation
# P(U|T)= 0.03125
#
#
# Tag mayuresh
# P(U|T)= 0.026041666666666664
#
#
# Tag robotics
# P(U|T)= 0.03125
#
#
# *************************************************************
# User 10000389 7
# Tag automation anywhere
# P(U|T)= 0.10670302579240436
#
#
# Tag learn
# P(U|T)= 0.038873213518984234
#
#
# Tag robotic process automation
# P(U|T)= 0.0196078431372549
#
#
# Tag kileshwar
# P(U|T)= 0.015172735760971053
#
#
# Tag cyber security
# P(U|T)= 0.0196078431372549
#
#
# *************************************************************
# User 10000367 8
# Tag bigdata
# P(U|T)= 0.06481481481481481
#
#
# Tag automation anywhere
# P(U|T)= 0.004250659398032315
#
#
# Tag learn
# P(U|T)= 0.1944444444444444
#
#
# Tag robotics
# P(U|T)= 0.05555555555555555
#
#
# *************************************************************
# User 10000390 9
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.024871794871794868
#
#
# Tag bigdata
# P(U|T)= 0.006666666666666666
#
#
# Tag automation anywhere
# P(U|T)= 0.07591172646234584
#
#
# Tag learn
# P(U|T)= 0.023051656372824258
#
#
# Tag the art
# P(U|T)= 0.01
#
#
# Tag robotic process automation
# P(U|T)= 0.01
#
#
# Tag kileshwar
# P(U|T)= 0.01
#
#
# Tag data structure
# P(U|T)= 0.006666666666666666
#
#
# Tag cyber security
# P(U|T)= 0.048461538461538466
#
#
# *************************************************************
# User 10000000 10
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.00041152263374485596
#
#
# Tag bigdata
# P(U|T)= 0.0024691358024691358
#
#
# Tag automation anywhere
# P(U|T)= 0.009552977265391576
#
#
# Tag learn
# P(U|T)= 0.004192896407008329
#
#
# Tag online yoga
# P(U|T)= 0.05502645502645502
#
#
# Tag html
# P(U|T)= 0.003703703703703704
#
#
# Tag robotic process automation
# P(U|T)= 0.053703703703703705
#
#
# Tag soft skills
# P(U|T)= 0.0775132275132275
#
#
# Tag digital marketing
# P(U|T)= 0.003703703703703704
#
#
# Tag social
# P(U|T)= 0.003703703703703704
#
#
# Tag mayuresh
# P(U|T)= 0.019841269841269837
#
#
# Tag kileshwar
# P(U|T)= 0.01164021164021164
#
#
# Tag ios 13
# P(U|T)= 0.023809523809523808
#
#
# Tag robotics
# P(U|T)= 0.003703703703703704
#
#
# Tag data structure
# P(U|T)= 0.017901234567901235
#
#
# Tag cyber security
# P(U|T)= 0.003703703703703704
#
#
# *************************************************************
# User 10000419 11
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.10755180240920532
#
#
# Tag bigdata
# P(U|T)= 0.002157497303128371
#
#
# Tag automation anywhere
# P(U|T)= 0.03404908597660326
#
#
# Tag learn
# P(U|T)= 0.0015393821998598413
#
#
# Tag online yoga
# P(U|T)= 0.006472491909385114
#
#
# Tag the art
# P(U|T)= 0.03448624595469256
#
#
# Tag html
# P(U|T)= 0.03448624595469256
#
#
# Tag robotic process automation
# P(U|T)= 0.003236245954692557
#
#
# Tag digital marketing
# P(U|T)= 0.003236245954692557
#
#
# Tag social
# P(U|T)= 0.03448624595469256
#
#
# Tag mayuresh
# P(U|T)= 0.0032362459546925564
#
#
# Tag kileshwar
# P(U|T)= 0.007905204962243798
#
#
# Tag robotics
# P(U|T)= 0.003236245954692557
#
#
# Tag data structure
# P(U|T)= 0.011495415318230853
#
#
# Tag cyber security
# P(U|T)= 0.03448624595469256
#
#
# *************************************************************
# User 5e982b102cab0 12
# *************************************************************
# User 10000421 13
# *************************************************************
# User 10000417 14
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.022222222222222223
#
#
# Tag bigdata
# P(U|T)= 0.005333333333333333
#
#
# Tag automation anywhere
# P(U|T)= 0.3048852220255894
#
#
# Tag learn
# P(U|T)= 0.10823357664233577
#
#
# Tag the art
# P(U|T)= 0.008
#
#
# Tag html
# P(U|T)= 0.008
#
#
# Tag digital marketing
# P(U|T)= 0.048
#
#
# Tag social
# P(U|T)= 0.24800000000000003
#
#
# Tag mayuresh
# P(U|T)= 0.0013333333333333333
#
#
# Tag sql server administration part1
# P(U|T)= 0.008
#
#
# Tag kileshwar
# P(U|T)= 0.018666666666666665
#
#
# Tag robotics
# P(U|T)= 0.008
#
#
# Tag cyber security
# P(U|T)= 0.048
#
#
# *************************************************************
# User 10000413 15
# Tag automation anywhere
# P(U|T)= 0.14723683203656093
#
#
# Tag learn
# P(U|T)= 0.054486886315545546
#
#
# Tag digital marketing
# P(U|T)= 0.2675438596491228
#
#
# Tag kileshwar
# P(U|T)= 0.005847953216374269
#
#
# Tag robotics
# P(U|T)= 0.017543859649122806
#
#
# Tag data structure
# P(U|T)= 0.023809523809523808
#
#
# *************************************************************
# User 10000218 16
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.015555555555555555
#
#
# Tag automation anywhere
# P(U|T)= 0.08523765676948077
#
#
# Tag learn
# P(U|T)= 0.02656934306569343
#
#
# Tag html
# P(U|T)= 0.022222222222222223
#
#
# Tag digital marketing
# P(U|T)= 0.022222222222222223
#
#
# Tag social
# P(U|T)= 0.022222222222222223
#
#
# Tag mayuresh
# P(U|T)= 0.003703703703703704
#
#
# Tag data structure
# P(U|T)= 0.013333333333333332
#
#
# *************************************************************
# User 10000420 17
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.003502415458937198
#
#
# Tag automation anywhere
# P(U|T)= 0.05890755922589215
#
#
# Tag learn
# P(U|T)= 0.015113528172874412
#
#
# Tag the art
# P(U|T)= 0.004347826086956522
#
#
# Tag html
# P(U|T)= 0.004347826086956522
#
#
# Tag robotic process automation
# P(U|T)= 0.004347826086956522
#
#
# Tag soft skills
# P(U|T)= 0.004347826086956522
#
#
# Tag digital marketing
# P(U|T)= 0.03465085638998683
#
#
# Tag social
# P(U|T)= 0.004347826086956522
#
#
# Tag mayuresh
# P(U|T)= 0.004347826086956521
#
#
# Tag kileshwar
# P(U|T)= 0.023825208607817304
#
#
# Tag robotics
# P(U|T)= 0.004347826086956522
#
#
# Tag data structure
# P(U|T)= 0.012999560825647781
#
#
# *************************************************************
# User 5e984ae3020be 18
# Tag bigdata
# P(U|T)= 0.16666666666666666
#
#
# *************************************************************
# User 5e984d563502b 19
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 10000368 20
# Tag bigdata
# P(U|T)= 0.14887436456063907
#
#
# Tag automation anywhere
# P(U|T)= 0.07454563833855403
#
#
# Tag learn
# P(U|T)= 0.0241877773007013
#
#
# Tag online yoga
# P(U|T)= 0.37254901960784315
#
#
# Tag digital marketing
# P(U|T)= 0.16666666666666666
#
#
# Tag kileshwar
# P(U|T)= 0.07116920842411038
#
#
# Tag robotics
# P(U|T)= 0.0196078431372549
#
#
# Tag cyber security
# P(U|T)= 0.05664488017429194
#
#
# *************************************************************
# User 10000287 21
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.003205128205128205
#
#
# Tag bigdata
# P(U|T)= 0.012173290368779089
#
#
# Tag automation anywhere
# P(U|T)= 0.06747936816196497
#
#
# Tag learn
# P(U|T)= 0.04436856157398389
#
#
# Tag mayuresh
# P(U|T)= 0.017006802721088433
#
#
# Tag ios 13
# P(U|T)= 0.038461538461538464
#
#
# Tag data structure
# P(U|T)= 0.013605442176870746
#
#
# *************************************************************
# User 10000369 22
# *************************************************************
# User 10000359 23
# Tag bigdata
# P(U|T)= 0.14469696969696969
#
#
# Tag automation anywhere
# P(U|T)= 0.021857816366420743
#
#
# Tag learn
# P(U|T)= 0.004852355673523556
#
#
# Tag robotic process automation
# P(U|T)= 0.011363636363636364
#
#
# Tag mayuresh
# P(U|T)= 0.00946969696969697
#
#
# Tag kileshwar
# P(U|T)= 0.05876623376623376
#
#
# Tag ios 13
# P(U|T)= 0.011363636363636364
#
#
# Tag robotics
# P(U|T)= 0.2
#
#
# Tag data structure
# P(U|T)= 0.003787878787878788
#
#
# Tag cyber security
# P(U|T)= 0.04707792207792208
#
#
# *************************************************************
# User 10000427 24
# *************************************************************
# User 5e97310dbcae7 25
# *************************************************************
# User 5e9880c9a4ffc 26
# *************************************************************
# User 10000424 27
# *************************************************************
# User 5e9578d645c3c 28
# *************************************************************
# User 10000418 29
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.03418803418803419
#
#
# Tag bigdata
# P(U|T)= 0.04934640522875817
#
#
# Tag automation anywhere
# P(U|T)= 0.17380658528540274
#
#
# Tag learn
# P(U|T)= 0.06445362816659511
#
#
# Tag kileshwar
# P(U|T)= 0.0754713423831071
#
#
# Tag data structure
# P(U|T)= 0.0024509803921568627
#
#
# *************************************************************
# User 5e988bd975d1c 30
# *************************************************************
# User 10000048 31
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.016313932980599646
#
#
# Tag automation anywhere
# P(U|T)= 0.02578859774960342
#
#
# Tag robotic process automation
# P(U|T)= 0.03571428571428571
#
#
# Tag soft skills
# P(U|T)= 0.03571428571428571
#
#
# Tag sql server administration part1
# P(U|T)= 0.09126984126984126
#
#
# Tag data structure
# P(U|T)= 0.06084656084656084
#
#
# *************************************************************
# User 10000394 32
# *************************************************************
# User 10000294 33
# Tag bigdata
# P(U|T)= 0.043750000000000004
#
#
# Tag mayuresh
# P(U|T)= 0.11111111111111109
#
#
# Tag kileshwar
# P(U|T)= 0.01875
#
#
# Tag ios 13
# P(U|T)= 0.03125
#
#
# Tag robotics
# P(U|T)= 0.1111111111111111
#
#
# Tag data structure
# P(U|T)= 0.03333333333333333
#
#
# *************************************************************
# User 5e99b9ab3fabe 34
# *************************************************************
# User 5e99c5a6e06ff 35
# *************************************************************
# User 10000370 36
# *************************************************************
# User 10000234 37
# Tag automation anywhere
# P(U|T)= 0.03245958085770131
#
#
# Tag soft skills
# P(U|T)= 0.09090909090909091
#
#
# *************************************************************
# User 10000397 38
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.0404040404040404
#
#
# Tag learn
# P(U|T)= 0.004423800044238
#
#
# *************************************************************
# User 5e9a9dae99aba 39
# Tag bigdata
# P(U|T)= 0.2222222222222222
#
#
# *************************************************************
# User 5e9aa10f9e498 40
# Tag bigdata
# P(U|T)= 0.07407407407407407
#
#
# Tag learn
# P(U|T)= 0.05825898891592321
#
#
# *************************************************************
# User 10000406 41
# Tag automation anywhere
# P(U|T)= 0.2021700806194612
#
#
# Tag learn
# P(U|T)= 0.07116788321167884
#
#
# Tag cyber security
# P(U|T)= 0.06666666666666667
#
#
# *************************************************************
# User 10000430 42
# Tag automation anywhere
# P(U|T)= 0.3249162009955626
#
#
# Tag learn
# P(U|T)= 0.11437695516162669
#
#
# Tag cyber security
# P(U|T)= 0.125
#
#
# *************************************************************
# User 10000289 43
# Tag automation anywhere
# P(U|T)= 0.010440186326559672
#
#
# Tag mayuresh
# P(U|T)= 0.27777777777777773
#
#
# Tag kileshwar
# P(U|T)= 0.011904761904761904
#
#
# Tag ios 13
# P(U|T)= 0.05
#
#
# Tag robotics
# P(U|T)= 0.05
#
#
# *************************************************************
# User 10000357 44
# Tag automation anywhere
# P(U|T)= 1.0694945955030164
#
#
# Tag learn
# P(U|T)= 0.48826903023983304
#
#
# Tag kileshwar
# P(U|T)= 0.023809523809523808
#
#
# *************************************************************
# User 10000375 45
# *************************************************************
# User 10000426 46
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.02979066022544283
#
#
# Tag bigdata
# P(U|T)= 0.05369751021924935
#
#
# Tag automation anywhere
# P(U|T)= 0.2111395842924315
#
#
# Tag learn
# P(U|T)= 0.06306970450297966
#
#
# Tag html
# P(U|T)= 0.0661231884057971
#
#
# Tag robotic process automation
# P(U|T)= 0.0036231884057971015
#
#
# Tag digital marketing
# P(U|T)= 0.0036231884057971015
#
#
# Tag sql server administration part1
# P(U|T)= 0.0036231884057971015
#
#
# Tag kileshwar
# P(U|T)= 0.025652638424377556
#
#
# Tag robotics
# P(U|T)= 0.0036231884057971015
#
#
# Tag data structure
# P(U|T)= 0.0012077294685990338
#
#
# Tag cyber security
# P(U|T)= 0.0036231884057971015
#
#
# *************************************************************
# User 10000055 47
# *************************************************************
# User 10000414 48
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.013888888888888888
#
#
# Tag automation anywhere
# P(U|T)= 0.9472200609561777
#
#
# Tag learn
# P(U|T)= 0.3691833941605839
#
#
# Tag kileshwar
# P(U|T)= 0.005208333333333333
#
#
# *************************************************************
# User 5e9d3e96051ca 49
# *************************************************************
# User 5e9d46f21df43 50
# Tag digital marketing
# P(U|T)= 1.0
#
#
# *************************************************************
# User 10000013 51
# Tag bigdata
# P(U|T)= 0.013605442176870746
#
#
# Tag automation anywhere
# P(U|T)= 0.03185769456375947
#
#
# Tag learn
# P(U|T)= 0.00871443467898108
#
#
# Tag robotic process automation
# P(U|T)= 0.07596371882086167
#
#
# Tag digital marketing
# P(U|T)= 0.02040816326530612
#
#
# Tag kileshwar
# P(U|T)= 0.0034013605442176865
#
#
# Tag robotics
# P(U|T)= 0.1388888888888889
#
#
# *************************************************************
# User 10000286 52
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.012345679012345678
#
#
# Tag bigdata
# P(U|T)= 0.005208333333333333
#
#
# Tag mayuresh
# P(U|T)= 0.026041666666666664
#
#
# Tag sql server administration part1
# P(U|T)= 0.1111111111111111
#
#
# Tag kileshwar
# P(U|T)= 0.005208333333333333
#
#
# Tag robotics
# P(U|T)= 0.1111111111111111
#
#
# Tag data structure
# P(U|T)= 0.0474537037037037
#
#
# Tag cyber security
# P(U|T)= 0.3333333333333333
#
#
# *************************************************************
# User 10000302 53
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.004192872117400419
#
#
# Tag bigdata
# P(U|T)= 0.006289308176100628
#
#
# Tag automation anywhere
# P(U|T)= 0.05211700706122672
#
#
# Tag learn
# P(U|T)= 0.029235378931242676
#
#
# Tag online yoga
# P(U|T)= 0.018867924528301886
#
#
# Tag html
# P(U|T)= 0.009433962264150943
#
#
# Tag mayuresh
# P(U|T)= 0.03503086419753086
#
#
# Tag kileshwar
# P(U|T)= 0.011911833216864662
#
#
# Tag ios 13
# P(U|T)= 0.009433962264150943
#
#
# Tag data structure
# P(U|T)= 0.01981132075471698
#
#
# Tag cyber security
# P(U|T)= 0.009433962264150943
#
#
# *************************************************************
# User 5e9da8df05744 54
# *************************************************************
# User 5e9db8b35aee1 55
# Tag robotic process automation
# P(U|T)= 1.0
#
#
# *************************************************************
# User 5e9dbe157cae6 56
# Tag html
# P(U|T)= 0.3333333333333333
#
#
# *************************************************************
# User 10000366 57
# *************************************************************
# User 5e9dcb1744639 58
# *************************************************************
# User 5e9de2d595d01 59
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 10000081 60
# Tag automation anywhere
# P(U|T)= 0.030987479130580364
#
#
# Tag learn
# P(U|T)= 0.006258803944166986
#
#
# Tag robotic process automation
# P(U|T)= 0.07692307692307693
#
#
# Tag mayuresh
# P(U|T)= 0.01282051282051282
#
#
# Tag kileshwar
# P(U|T)= 0.01501349527665317
#
#
# Tag data structure
# P(U|T)= 0.013333333333333332
#
#
# Tag cyber security
# P(U|T)= 0.013157894736842105
#
#
# *************************************************************
# User 5e9de885dea60 61
# *************************************************************
# User 5e9debb917b26 62
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 5e9e8dfe482dd 63
# *************************************************************
# User 5e9e99ed47212 64
# *************************************************************
# User 5e9ec6df4ec06 65
# *************************************************************
# User 10000376 66
# Tag bigdata
# P(U|T)= 0.041666666666666664
#
#
# Tag automation anywhere
# P(U|T)= 0.7879832477867503
#
#
# Tag learn
# P(U|T)= 0.27281021897810215
#
#
# *************************************************************
# User 5e9ae16309045 67
# *************************************************************
# User 5e9db436d776b 68
# Tag automation anywhere
# P(U|T)= 0.07651186916458168
#
#
# *************************************************************
# User 5e9f0200665ec 69
# *************************************************************
# User 5e9f031c76532 70
# *************************************************************
# User 5e9f04e975bfc 71
# *************************************************************
# User 5e9f0b41d6061 72
# *************************************************************
# User 5e9f3134c740a 73
# Tag bigdata
# P(U|T)= 0.6666666666666666
#
#
# *************************************************************
# User 5ea00d01019bf 74
# *************************************************************
# User 5ea00f958a9c0 75
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 5ea010b570e44 76
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 5ea0181600210 77
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 5ea018da3b305 78
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 5ea01a61ecd64 79
# Tag automation anywhere
# P(U|T)= 0.025503956388193888
#
#
# *************************************************************
# User 5ea024adbd3fd 80
# *************************************************************
# User 5ea02b54ace6a 81
# *************************************************************
# User 5ea02c2d59110 82
# *************************************************************
# User 5ea02ee9bc9f3 83
# Tag automation anywhere
# P(U|T)= 0.009563983645572708
#
#
# Tag digital marketing
# P(U|T)= 0.125
#
#
# Tag kileshwar
# P(U|T)= 0.020833333333333332
#
#
# *************************************************************
# User 5ea039f0e873d 84
# *************************************************************
# User 426806 85
# *************************************************************
# User 5e9eb5ad1cb2e 86
# Tag automation anywhere
# P(U|T)= 0.03825593458229084
#
#
# *************************************************************
# User 993322 87
# *************************************************************
# User 396236 88
# Tag kileshwar
# P(U|T)= 0.08333333333333333
#
#
# *************************************************************
# User 42651 89
# Tag automation anywhere
# P(U|T)= 0.07651186916458168
#
#
# *************************************************************
# User 265521 90
# *************************************************************
# User 879077 91
# Tag kileshwar
# P(U|T)= 0.16666666666666666
#
#
# *************************************************************
# User 10000404 92
# Tag learn
# P(U|T)= 0.0121654501216545
#
#
# *************************************************************
# User 190085 93
# Tag automation anywhere
# P(U|T)= 0.07651186916458168
#
#
# *************************************************************
# User 857383 94
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 9537 95
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 567186 96
# *************************************************************
# User 10000434 97
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.13762880073855682
#
#
# Tag bigdata
# P(U|T)= 0.05534709193245779
#
#
# Tag automation anywhere
# P(U|T)= 0.19996442216773763
#
#
# Tag learn
# P(U|T)= 0.06360474579719728
#
#
# Tag the art
# P(U|T)= 0.006097560975609756
#
#
# Tag digital marketing
# P(U|T)= 0.1489547038327526
#
#
# Tag social
# P(U|T)= 0.006097560975609756
#
#
# Tag kileshwar
# P(U|T)= 0.027673545966228896
#
#
# Tag data structure
# P(U|T)= 0.002032520325203252
#
#
# Tag cyber security
# P(U|T)= 0.006097560975609756
#
#
# *************************************************************
# User  98
# Tag automation anywhere
# P(U|T)= 0.047054236759490914
#
#
# Tag kileshwar
# P(U|T)= 0.018518518518518517
#
#
# *************************************************************
# User 10000402 99
# Tag automation anywhere
# P(U|T)= 0.017002637592129256
#
#
# Tag learn
# P(U|T)= 0.005406866720735333
#
#
# Tag kileshwar
# P(U|T)= 0.037037037037037035
#
#
# Tag robotics
# P(U|T)= 0.1111111111111111
#
#
# *************************************************************
# User 208885 100
# Tag automation anywhere
# P(U|T)= 0.07651186916458168
#
#
# *************************************************************
# User 10000436 101
# *************************************************************
# User 13840 102
# Tag automation anywhere
# P(U|T)= 0.15302373832916333
#
#
# *************************************************************
# User 10000432 103
# *************************************************************
# User 431230 104
# *************************************************************
# User 610668 105
# *************************************************************
# User 983312 106
# Tag learn
# P(U|T)= 0.048661800486618
#
#
# *************************************************************
# User 10000037 107
# Tag bigdata
# P(U|T)= 0.020833333333333332
#
#
# Tag automation anywhere
# P(U|T)= 0.5508516235769545
#
#
# Tag learn
# P(U|T)= 0.19571167883211676
#
#
# *************************************************************
# User 788728 108
# *************************************************************
# User 10000440 109
# Tag automation anywhere
# P(U|T)= 0.02397741681167568
#
#
# Tag learn
# P(U|T)= 0.00901042050677087
#
#
# Tag cyber security
# P(U|T)= 0.11868686868686867
#
#
# *************************************************************
# User 647542 110
# Tag kileshwar
# P(U|T)= 0.16666666666666666
#
#
# *************************************************************
# User 114552 111
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.25
#
#
# Tag automation anywhere
# P(U|T)= 0.07651186916458168
#
#
# *************************************************************
# User 10000439 112
# Tag automation anywhere
# P(U|T)= 0.2586405123587838
#
#
# Tag learn
# P(U|T)= 0.09101997694967345
#
#
# Tag kileshwar
# P(U|T)= 0.020711500974658868
#
#
# Tag robotics
# P(U|T)= 0.013157894736842105
#
#
# Tag data structure
# P(U|T)= 0.06666666666666667
#
#
# *************************************************************
# User 10000444 113
# *************************************************************
# User 194270 114
# *************************************************************
# User 10000410 115
# Tag automation anywhere
# P(U|T)= 0.5477899147698377
#
#
# Tag learn
# P(U|T)= 0.21350364963503649
#
#
# Tag data structure
# P(U|T)= 0.16666666666666666
#
#
# *************************************************************
# User 976794 116
# Tag data structure
# P(U|T)= 0.3333333333333333
#
#
# *************************************************************
# User 10000322 117
# Tag automation anywhere
# P(U|T)= 0.010930267023511665
#
#
# Tag robotic process automation
# P(U|T)= 0.3333333333333333
#
#
# Tag robotics
# P(U|T)= 0.14285714285714285
#
#
# Tag data structure
# P(U|T)= 0.05555555555555555
#
#
# *************************************************************
# User 74454 118
# Tag automation anywhere
# P(U|T)= 1.0955798295396755
#
#
# Tag learn
# P(U|T)= 0.42700729927007297
#
#
# *************************************************************
# User 526964 119
# Tag automation anywhere
# P(U|T)= 0.5860458493521286
#
#
# Tag learn
# P(U|T)= 0.21350364963503649
#
#
# *************************************************************
# User 10000364 120
# Tag kileshwar
# P(U|T)= 0.03333333333333333
#
#
# Tag cyber security
# P(U|T)= 0.5333333333333333
#
#
# *************************************************************
# User 252522 121
# *************************************************************
# User 121610 122
# Tag automation anywhere
# P(U|T)= 0.025503956388193888
#
#
# *************************************************************
# User 73735 123
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 10000446 124
# Tag cyber security
# P(U|T)= 0.2
#
#
# *************************************************************
# User 993303 125
# Tag learn
# P(U|T)= 0.24999999999999997
#
#
# *************************************************************
# User 10000356 126
# Tag robotics
# P(U|T)= 0.3333333333333333
#
#
# *************************************************************
# User 10000449 127
# Tag soft skills
# P(U|T)= 0.2
#
#
# *************************************************************
# User 357608 128
# *************************************************************
# User 38660 129
# *************************************************************
# User 282678 130
# *************************************************************
# User 150714 131
# Tag learn
# P(U|T)= 0.048661800486618
#
#
# *************************************************************
# User 281970 132
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 802690 133
# *************************************************************
# User 151021 134
# *************************************************************
# User 803360 135
# Tag automation anywhere
# P(U|T)= 0.025503956388193888
#
#
# Tag cyber security
# P(U|T)= 0.3333333333333333
#
#
# *************************************************************
# User 171752 136
# *************************************************************
# User 10000441 137
# *************************************************************
# User 931158 138
# *************************************************************
# User 480730 139
# *************************************************************
# User 10000393 140
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 10000457 141
# Tag the complete sql bootcamp 2020
# P(U|T)= 0.007575757575757576
#
#
# Tag automation anywhere
# P(U|T)= 0.052167183521305685
#
#
# *************************************************************
# User 593618 142
# *************************************************************
# User 73619 143
# *************************************************************
# User 247642 144
# *************************************************************
# User 504493 145
# Tag automation anywhere
# P(U|T)= 0.039146884725697204
#
#
# *************************************************************
# User 441086 146
# Tag automation anywhere
# P(U|T)= 0.025503956388193888
#
#
# *************************************************************
# User 58979 147
# *************************************************************
# User 125396 148
# *************************************************************
# User 10000458 149
# Tag automation anywhere
# P(U|T)= 0.007651186916458167
#
#
# *************************************************************
# User 202679 150
# *************************************************************
# User 187741 151
# *************************************************************
# User 10000456 152
# *************************************************************
# User 10000431 153
# *************************************************************
# User 790617 154
# *************************************************************
# User 773036 155
# *************************************************************
# User 603834 156
# Tag cyber security
# P(U|T)= 1.0
#
#
# *************************************************************
# User 649483 157
# Tag online yoga
# P(U|T)= 2.0
#
#
# *************************************************************
# User 597328 158
# Tag data structure
# P(U|T)= 0.3333333333333333
#
#
# *************************************************************
# User 10000459 159
# Tag automation anywhere
# P(U|T)= 0.01067642310700833
#
#
# *************************************************************
# User 610577 160
# *************************************************************
# User 656219 161
# *************************************************************
# User 477656 162
# *************************************************************
# User 10000080 163
# Tag automation anywhere
# P(U|T)= 0.025503956388193888
#
#
# Tag online yoga
# P(U|T)= 0.5
#
#
# Tag robotics
# P(U|T)= 0.35
#
#
# *************************************************************
# User 10000462 164
# *************************************************************
# User 10000461 165
# *************************************************************
# User 10000187 166
# *************************************************************
# User 10000465 167
# Tag kileshwar
# P(U|T)= 0.03333333333333333
#
#
# *************************************************************
# User 10000099 168
# Tag robotics
# P(U|T)= 0.16666666666666666
#
#
# *************************************************************
# User 10000104 169
# *************************************************************
# User 10000079 170
# *************************************************************
# User 10000083 171
# Tag robotics
# P(U|T)= 0.08333333333333333
#
#
# *************************************************************
# User 10000106 172
# *************************************************************
# User 10000078 173
# Tag automation anywhere
# P(U|T)= 0.04250659398032315
#
#
# Tag online yoga
# P(U|T)= 0.1111111111111111
#
#
# Tag robotics
# P(U|T)= 0.05555555555555555
#
#
# *************************************************************
# User 419728 174
# *************************************************************
# User 585302 175
# *************************************************************
# User 842135 176
# Tag online yoga
# P(U|T)= 0.6666666666666666
#
#
# *************************************************************
# User 10000220 177
# *************************************************************
# User 10000270 178
# Tag robotics
# P(U|T)= 0.5
#
#
# *************************************************************
# User 148390 179
# Tag robotics
# P(U|T)= 0.3333333333333333
#
#
# *************************************************************
# User 859170 180
# Tag robotics
# P(U|T)= 0.3333333333333333
#
#
# *************************************************************
# User 10000215 181
# *************************************************************
# User 597457 182
# *************************************************************
# User 10000140 183
# *************************************************************
# User 10000033 184
# Tag automation anywhere
# P(U|T)= 0.03825593458229083
#
#
# *************************************************************
# User 10000288 185
# Tag robotics
# P(U|T)= 1.0
#
#
# *************************************************************
# User 10000200 186
# Tag automation anywhere
# P(U|T)= 0.012751978194096944
#
#
# Tag online yoga
# P(U|T)= 0.3333333333333333
#
#
# Tag robotics
# P(U|T)= 0.16666666666666666
#
#
# *************************************************************
# User 615538 187
# *************************************************************
# User 10000227 188
# *************************************************************
# User 600564 189
# *************************************************************
# User 10000232 190
# Tag automation anywhere
# P(U|T)= 0.03825593458229083
#
#
# Tag robotics
# P(U|T)= 1.0
#
#
# *************************************************************
# User 10000264 191
# *************************************************************
# User 10000247 192
# Tag robotics
# P(U|T)= 0.25
#
#
# *************************************************************
# User 10000349 193
# Tag online yoga
# P(U|T)= 0.4
#
#
# *************************************************************
# User 957490 194
# *************************************************************
# User 10000261 195
# Tag automation anywhere
# P(U|T)= 0.011243277582448878
#
#
# Tag kileshwar
# P(U|T)= 0.01282051282051282
#
#
# Tag ios 13
# P(U|T)= 0.07692307692307693
#
#
# *************************************************************
# User 107973 196
# Tag mayuresh
# P(U|T)= 0.41666666666666663
#
#
# *************************************************************
# User 10000138 197
# *************************************************************
# User 10000297 198
# Tag automation anywhere
# P(U|T)= 0.03825593458229083
#
#
# Tag robotics
# P(U|T)= 0.5
#
#
# *************************************************************
# User 10000326 199
# *************************************************************
# User 10000360 200
# Tag robotics
# P(U|T)= 0.16666666666666666
#
#
# *************************************************************
# User 10000298 201
# *************************************************************
# User 917319 202
# Tag automation anywhere
# P(U|T)= 0.019127967291145416
#
#
# Tag robotics
# P(U|T)= 0.25
#
#
# *************************************************************
# User 10000279 203
# *************************************************************
# User 10000335 204
# *************************************************************
# User 10000253 205
# *************************************************************
# User 86298 206
# *************************************************************
# User 10000331 207
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 10000351 208
# *************************************************************
# User 10000340 209
# Tag automation anywhere
# P(U|T)= 0.005885528397275513
#
#
# Tag mayuresh
# P(U|T)= 0.0641025641025641
#
#
# Tag robotics
# P(U|T)= 0.07692307692307693
#
#
# *************************************************************
# User 803279 210
# *************************************************************
# User 10000352 211
# Tag automation anywhere
# P(U|T)= 0.07651186916458166
#
#
# *************************************************************
# User 10000378 212
# Tag learn
# P(U|T)= 0.004866180048661801
#
#
# Tag mayuresh
# P(U|T)= 0.03333333333333333
#
#
# *************************************************************
# User 144014 213
# Tag automation anywhere
# P(U|T)= 0.025503956388193888
#
#
# *************************************************************
# User 332792 214
# Tag robotics
# P(U|T)= 0.25
#
#
# *************************************************************
# User 10000395 215
# *************************************************************
# User 2147483647 216
# Tag bigdata
# P(U|T)= 0.0044742729306487695
#
#
# Tag automation anywhere
# P(U|T)= 0.0010270049552292843
#
#
# Tag learn
# P(U|T)= 0.0035189993304920062
#
#
# Tag html
# P(U|T)= 0.006711409395973154
#
#
# Tag robotic process automation
# P(U|T)= 0.006711409395973154
#
#
# Tag social
# P(U|T)= 0.006711409395973154
#
#
# Tag kileshwar
# P(U|T)= 0.0022371364653243847
#
#
# *************************************************************
# User 10000398 217
# Tag data structure
# P(U|T)= 0.3333333333333333
#
#
# *************************************************************
# User 10000470 218
# *************************************************************
# User 10000463 219
# *************************************************************
# User 579765 220

# %%
c_list = graph_handler.because_you_searched('sql',course_tag_profile)
for c in c_list:
   print("Course {} Name {}".format(c,course_details.get(c.strip(" "),"")))
# Out:
# Course 608158782373810000420 Name The Complete SQL Bootcamp 2020
# Course 757158798294310000420 Name The Complete Personal Finance Course
# Course 245156760451710000000 Name MySQL
# Course 261156788006210000000 Name SQL Server Administration Part1
# Course 559158644019010000287 Name Requirements Gathering Techniques for a Software Development (Copy0)

# %%
c_list = graph_handler.because_you_searched('social',course_tag_profile)
for c in c_list:
   print("Course {} Name {}".format(c,course_details.get(c.strip(" "),"")))
# Out:
# Course 470158701696410000420 Name Learn Social Psychology

# %%
final_user_structure = {}
final_user_set = {}
for u1 in users:
  # Recomendation system for finding out the courses similar to a given course by finding out the inner product of 
  # courses 
  print("****************************************************")
  print("User:u1",u1)
  u2_arr =[]
  user_set = []
  for u2 in users:
    user_score = np.sum(np.inner(np.array(user_tag_profile.loc[u1,:]),np.array(user_tag_profile.loc[u2,:])))
    if user_score>0.04:
      u2_arr.append([u2,user_score])
      user_set.append(u2)
      print("SIMILAR USERS", u2)
  print('\n')
  u2_arr = sorted(u2_arr,key = itemgetter(1),reverse=True)
  final_user_structure[u1] = u2_arr
  final_user_set[u1] = user_set
# Out:
# ****************************************************
# User:u1 10000372
#
#
# ****************************************************
# User:u1 10000386
#
#
# ****************************************************
# User:u1 10000391
#
#
# ****************************************************
# User:u1 10000282
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 10000270
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 10000297
#
#
# ****************************************************
# User:u1 10000299
# SIMILAR USERS 10000270
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 10000297
#
#
# ****************************************************
# User:u1 10000416
# SIMILAR USERS 10000416
# SIMILAR USERS 10000417
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000434
# SIMILAR USERS 10000037
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 603834
#
#
# ****************************************************
# User:u1 10000422
#
#
# ****************************************************
# User:u1 10000389
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000367
# SIMILAR USERS 10000367
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 5e9f3134c740a
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 993303
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
#
#
# ****************************************************
# User:u1 10000390
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 603834
#
#
# ****************************************************
# User:u1 10000000
# SIMILAR USERS 5e9db8b35aee1
# SIMILAR USERS 649483
#
#
# ****************************************************
# User:u1 10000419
#
#
# ****************************************************
# User:u1 5e982b102cab0
#
#
# ****************************************************
# User:u1 10000421
#
#
# ****************************************************
# User:u1 10000417
# SIMILAR USERS 10000416
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 5e9d46f21df43
# SIMILAR USERS 10000376
# SIMILAR USERS 10000434
# SIMILAR USERS 13840
# SIMILAR USERS 10000037
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 603834
#
#
# ****************************************************
# User:u1 10000413
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000368
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 5e9d46f21df43
# SIMILAR USERS 10000376
# SIMILAR USERS 10000434
# SIMILAR USERS 10000037
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000218
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000420
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 74454
#
#
# ****************************************************
# User:u1 5e984ae3020be
# SIMILAR USERS 5e9f3134c740a
#
#
# ****************************************************
# User:u1 5e984d563502b
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000368
# SIMILAR USERS 10000413
# SIMILAR USERS 10000368
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 5e9d46f21df43
# SIMILAR USERS 10000376
# SIMILAR USERS 5e9f3134c740a
# SIMILAR USERS 10000434
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 603834
# SIMILAR USERS 649483
# SIMILAR USERS 10000080
# SIMILAR USERS 10000078
# SIMILAR USERS 842135
# SIMILAR USERS 10000200
# SIMILAR USERS 10000349
#
#
# ****************************************************
# User:u1 10000287
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000369
#
#
# ****************************************************
# User:u1 10000359
# SIMILAR USERS 10000359
# SIMILAR USERS 5e9f3134c740a
# SIMILAR USERS 10000356
# SIMILAR USERS 603834
# SIMILAR USERS 10000080
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000427
#
#
# ****************************************************
# User:u1 5e97310dbcae7
#
#
# ****************************************************
# User:u1 5e9880c9a4ffc
#
#
# ****************************************************
# User:u1 10000424
#
#
# ****************************************************
# User:u1 5e9578d645c3c
#
#
# ****************************************************
# User:u1 10000418
# SIMILAR USERS 10000416
# SIMILAR USERS 10000417
# SIMILAR USERS 10000418
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000434
# SIMILAR USERS 10000037
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 5e988bd975d1c
#
#
# ****************************************************
# User:u1 10000048
#
#
# ****************************************************
# User:u1 10000394
#
#
# ****************************************************
# User:u1 10000294
# SIMILAR USERS 10000270
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 107973
# SIMILAR USERS 10000297
#
#
# ****************************************************
# User:u1 5e99b9ab3fabe
#
#
# ****************************************************
# User:u1 5e99c5a6e06ff
#
#
# ****************************************************
# User:u1 10000370
#
#
# ****************************************************
# User:u1 10000234
#
#
# ****************************************************
# User:u1 10000397
#
#
# ****************************************************
# User:u1 5e9a9dae99aba
# SIMILAR USERS 5e9a9dae99aba
# SIMILAR USERS 5e9f3134c740a
#
#
# ****************************************************
# User:u1 5e9aa10f9e498
# SIMILAR USERS 5e9f3134c740a
#
#
# ****************************************************
# User:u1 10000406
# SIMILAR USERS 10000416
# SIMILAR USERS 10000417
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000434
# SIMILAR USERS 10000037
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 603834
#
#
# ****************************************************
# User:u1 10000430
# SIMILAR USERS 10000416
# SIMILAR USERS 10000389
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 10000286
# SIMILAR USERS 10000376
# SIMILAR USERS 10000434
# SIMILAR USERS 13840
# SIMILAR USERS 10000037
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 10000364
# SIMILAR USERS 803360
# SIMILAR USERS 603834
#
#
# ****************************************************
# User:u1 10000289
# SIMILAR USERS 10000289
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 107973
#
#
# ****************************************************
# User:u1 10000357
# SIMILAR USERS 10000282
# SIMILAR USERS 10000416
# SIMILAR USERS 10000389
# SIMILAR USERS 10000367
# SIMILAR USERS 10000390
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000218
# SIMILAR USERS 10000420
# SIMILAR USERS 5e984d563502b
# SIMILAR USERS 10000368
# SIMILAR USERS 10000287
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 10000302
# SIMILAR USERS 5e9de2d595d01
# SIMILAR USERS 5e9debb917b26
# SIMILAR USERS 10000376
# SIMILAR USERS 5e9db436d776b
# SIMILAR USERS 5ea00f958a9c0
# SIMILAR USERS 5ea010b570e44
# SIMILAR USERS 5ea0181600210
# SIMILAR USERS 5ea018da3b305
# SIMILAR USERS 5e9eb5ad1cb2e
# SIMILAR USERS 42651
# SIMILAR USERS 190085
# SIMILAR USERS 857383
# SIMILAR USERS 9537
# SIMILAR USERS 10000434
# SIMILAR USERS
# SIMILAR USERS 208885
# SIMILAR USERS 13840
# SIMILAR USERS 10000037
# SIMILAR USERS 114552
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 73735
# SIMILAR USERS 993303
# SIMILAR USERS 281970
# SIMILAR USERS 10000393
# SIMILAR USERS 10000457
# SIMILAR USERS 504493
# SIMILAR USERS 10000078
# SIMILAR USERS 10000033
# SIMILAR USERS 10000232
# SIMILAR USERS 10000297
# SIMILAR USERS 10000331
# SIMILAR USERS 10000352
#
#
# ****************************************************
# User:u1 10000375
#
#
# ****************************************************
# User:u1 10000426
# SIMILAR USERS 10000416
# SIMILAR USERS 10000417
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000434
# SIMILAR USERS 10000037
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000055
#
#
# ****************************************************
# User:u1 10000414
# SIMILAR USERS 10000282
# SIMILAR USERS 10000416
# SIMILAR USERS 10000389
# SIMILAR USERS 10000367
# SIMILAR USERS 10000390
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000218
# SIMILAR USERS 10000420
# SIMILAR USERS 5e984d563502b
# SIMILAR USERS 10000368
# SIMILAR USERS 10000287
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 10000302
# SIMILAR USERS 5e9de2d595d01
# SIMILAR USERS 5e9debb917b26
# SIMILAR USERS 10000376
# SIMILAR USERS 5e9db436d776b
# SIMILAR USERS 5ea00f958a9c0
# SIMILAR USERS 5ea010b570e44
# SIMILAR USERS 5ea0181600210
# SIMILAR USERS 5ea018da3b305
# SIMILAR USERS 42651
# SIMILAR USERS 190085
# SIMILAR USERS 857383
# SIMILAR USERS 9537
# SIMILAR USERS 10000434
# SIMILAR USERS
# SIMILAR USERS 208885
# SIMILAR USERS 13840
# SIMILAR USERS 10000037
# SIMILAR USERS 114552
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 73735
# SIMILAR USERS 993303
# SIMILAR USERS 281970
# SIMILAR USERS 10000393
# SIMILAR USERS 10000457
# SIMILAR USERS 10000078
# SIMILAR USERS 10000331
# SIMILAR USERS 10000352
#
#
# ****************************************************
# User:u1 5e9d3e96051ca
#
#
# ****************************************************
# User:u1 5e9d46f21df43
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000368
# SIMILAR USERS 5e9d46f21df43
# SIMILAR USERS 5ea02ee9bc9f3
# SIMILAR USERS 10000434
#
#
# ****************************************************
# User:u1 10000013
# SIMILAR USERS 5e9db8b35aee1
# SIMILAR USERS 10000322
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 10000297
#
#
# ****************************************************
# User:u1 10000286
# SIMILAR USERS 10000430
# SIMILAR USERS 10000286
# SIMILAR USERS 10000364
# SIMILAR USERS 10000446
# SIMILAR USERS 803360
# SIMILAR USERS 603834
# SIMILAR USERS 10000270
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 10000297
#
#
# ****************************************************
# User:u1 10000302
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 74454
#
#
# ****************************************************
# User:u1 5e9da8df05744
#
#
# ****************************************************
# User:u1 5e9db8b35aee1
# SIMILAR USERS 10000000
# SIMILAR USERS 10000013
# SIMILAR USERS 5e9db8b35aee1
# SIMILAR USERS 10000081
# SIMILAR USERS 10000322
#
#
# ****************************************************
# User:u1 5e9dbe157cae6
# SIMILAR USERS 5e9dbe157cae6
#
#
# ****************************************************
# User:u1 10000366
#
#
# ****************************************************
# User:u1 5e9dcb1744639
#
#
# ****************************************************
# User:u1 5e9de2d595d01
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000081
# SIMILAR USERS 5e9db8b35aee1
#
#
# ****************************************************
# User:u1 5e9de885dea60
#
#
# ****************************************************
# User:u1 5e9debb917b26
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 5e9e8dfe482dd
#
#
# ****************************************************
# User:u1 5e9e99ed47212
#
#
# ****************************************************
# User:u1 5e9ec6df4ec06
#
#
# ****************************************************
# User:u1 10000376
# SIMILAR USERS 10000282
# SIMILAR USERS 10000416
# SIMILAR USERS 10000389
# SIMILAR USERS 10000367
# SIMILAR USERS 10000390
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000218
# SIMILAR USERS 10000420
# SIMILAR USERS 5e984d563502b
# SIMILAR USERS 10000368
# SIMILAR USERS 10000287
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 10000302
# SIMILAR USERS 5e9de2d595d01
# SIMILAR USERS 5e9debb917b26
# SIMILAR USERS 10000376
# SIMILAR USERS 5e9db436d776b
# SIMILAR USERS 5ea00f958a9c0
# SIMILAR USERS 5ea010b570e44
# SIMILAR USERS 5ea0181600210
# SIMILAR USERS 5ea018da3b305
# SIMILAR USERS 42651
# SIMILAR USERS 190085
# SIMILAR USERS 857383
# SIMILAR USERS 9537
# SIMILAR USERS 10000434
# SIMILAR USERS 208885
# SIMILAR USERS 13840
# SIMILAR USERS 10000037
# SIMILAR USERS 114552
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 73735
# SIMILAR USERS 993303
# SIMILAR USERS 281970
# SIMILAR USERS 10000393
# SIMILAR USERS 10000457
# SIMILAR USERS 10000331
# SIMILAR USERS 10000352
#
#
# ****************************************************
# User:u1 5e9ae16309045
#
#
# ****************************************************
# User:u1 5e9db436d776b
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 5e9f0200665ec
#
#
# ****************************************************
# User:u1 5e9f031c76532
#
#
# ****************************************************
# User:u1 5e9f04e975bfc
#
#
# ****************************************************
# User:u1 5e9f0b41d6061
#
#
# ****************************************************
# User:u1 5e9f3134c740a
# SIMILAR USERS 10000367
# SIMILAR USERS 5e984ae3020be
# SIMILAR USERS 10000368
# SIMILAR USERS 10000359
# SIMILAR USERS 5e9a9dae99aba
# SIMILAR USERS 5e9aa10f9e498
# SIMILAR USERS 5e9f3134c740a
#
#
# ****************************************************
# User:u1 5ea00d01019bf
#
#
# ****************************************************
# User:u1 5ea00f958a9c0
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 5ea010b570e44
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 5ea0181600210
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 5ea018da3b305
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 5ea01a61ecd64
#
#
# ****************************************************
# User:u1 5ea024adbd3fd
#
#
# ****************************************************
# User:u1 5ea02b54ace6a
#
#
# ****************************************************
# User:u1 5ea02c2d59110
#
#
# ****************************************************
# User:u1 5ea02ee9bc9f3
# SIMILAR USERS 5e9d46f21df43
#
#
# ****************************************************
# User:u1 5ea039f0e873d
#
#
# ****************************************************
# User:u1 426806
#
#
# ****************************************************
# User:u1 5e9eb5ad1cb2e
# SIMILAR USERS 10000357
# SIMILAR USERS 74454
#
#
# ****************************************************
# User:u1 993322
#
#
# ****************************************************
# User:u1 396236
#
#
# ****************************************************
# User:u1 42651
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 265521
#
#
# ****************************************************
# User:u1 879077
#
#
# ****************************************************
# User:u1 10000404
#
#
# ****************************************************
# User:u1 190085
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 857383
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 9537
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 567186
#
#
# ****************************************************
# User:u1 10000434
# SIMILAR USERS 10000416
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000368
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 5e9d46f21df43
# SIMILAR USERS 10000376
# SIMILAR USERS 10000434
# SIMILAR USERS 10000037
# SIMILAR USERS 114552
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 74454
#
#
# ****************************************************
# User:u1 10000402
# SIMILAR USERS 10000270
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 10000297
#
#
# ****************************************************
# User:u1 208885
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000436
#
#
# ****************************************************
# User:u1 13840
# SIMILAR USERS 10000417
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000432
#
#
# ****************************************************
# User:u1 431230
#
#
# ****************************************************
# User:u1 610668
#
#
# ****************************************************
# User:u1 983312
#
#
# ****************************************************
# User:u1 10000037
# SIMILAR USERS 10000282
# SIMILAR USERS 10000416
# SIMILAR USERS 10000389
# SIMILAR USERS 10000367
# SIMILAR USERS 10000390
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000218
# SIMILAR USERS 5e984d563502b
# SIMILAR USERS 10000368
# SIMILAR USERS 10000287
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 5e9de2d595d01
# SIMILAR USERS 5e9debb917b26
# SIMILAR USERS 10000376
# SIMILAR USERS 5e9db436d776b
# SIMILAR USERS 5ea00f958a9c0
# SIMILAR USERS 5ea010b570e44
# SIMILAR USERS 5ea0181600210
# SIMILAR USERS 5ea018da3b305
# SIMILAR USERS 42651
# SIMILAR USERS 190085
# SIMILAR USERS 857383
# SIMILAR USERS 9537
# SIMILAR USERS 10000434
# SIMILAR USERS 208885
# SIMILAR USERS 13840
# SIMILAR USERS 10000037
# SIMILAR USERS 114552
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 73735
# SIMILAR USERS 993303
# SIMILAR USERS 281970
# SIMILAR USERS 10000393
# SIMILAR USERS 10000331
# SIMILAR USERS 10000352
#
#
# ****************************************************
# User:u1 788728
#
#
# ****************************************************
# User:u1 10000440
# SIMILAR USERS 10000364
# SIMILAR USERS 803360
# SIMILAR USERS 603834
#
#
# ****************************************************
# User:u1 647542
#
#
# ****************************************************
# User:u1 114552
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000434
# SIMILAR USERS 10000037
# SIMILAR USERS 114552
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000439
# SIMILAR USERS 10000416
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000434
# SIMILAR USERS 10000037
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000444
#
#
# ****************************************************
# User:u1 194270
#
#
# ****************************************************
# User:u1 10000410
# SIMILAR USERS 10000282
# SIMILAR USERS 10000416
# SIMILAR USERS 10000389
# SIMILAR USERS 10000367
# SIMILAR USERS 10000390
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000218
# SIMILAR USERS 5e984d563502b
# SIMILAR USERS 10000368
# SIMILAR USERS 10000287
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 5e9de2d595d01
# SIMILAR USERS 5e9debb917b26
# SIMILAR USERS 10000376
# SIMILAR USERS 5e9db436d776b
# SIMILAR USERS 5ea00f958a9c0
# SIMILAR USERS 5ea010b570e44
# SIMILAR USERS 5ea0181600210
# SIMILAR USERS 5ea018da3b305
# SIMILAR USERS 42651
# SIMILAR USERS 190085
# SIMILAR USERS 857383
# SIMILAR USERS 9537
# SIMILAR USERS 10000434
# SIMILAR USERS 208885
# SIMILAR USERS 13840
# SIMILAR USERS 10000037
# SIMILAR USERS 114552
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 976794
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 73735
# SIMILAR USERS 993303
# SIMILAR USERS 281970
# SIMILAR USERS 10000393
# SIMILAR USERS 597328
# SIMILAR USERS 10000331
# SIMILAR USERS 10000352
# SIMILAR USERS 10000398
#
#
# ****************************************************
# User:u1 976794
# SIMILAR USERS 10000410
# SIMILAR USERS 976794
# SIMILAR USERS 597328
# SIMILAR USERS 10000398
#
#
# ****************************************************
# User:u1 10000322
# SIMILAR USERS 10000013
# SIMILAR USERS 5e9db8b35aee1
# SIMILAR USERS 10000322
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 10000297
#
#
# ****************************************************
# User:u1 74454
# SIMILAR USERS 10000282
# SIMILAR USERS 10000416
# SIMILAR USERS 10000389
# SIMILAR USERS 10000367
# SIMILAR USERS 10000390
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000218
# SIMILAR USERS 10000420
# SIMILAR USERS 5e984d563502b
# SIMILAR USERS 10000368
# SIMILAR USERS 10000287
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 10000302
# SIMILAR USERS 5e9de2d595d01
# SIMILAR USERS 5e9debb917b26
# SIMILAR USERS 10000376
# SIMILAR USERS 5e9db436d776b
# SIMILAR USERS 5ea00f958a9c0
# SIMILAR USERS 5ea010b570e44
# SIMILAR USERS 5ea0181600210
# SIMILAR USERS 5ea018da3b305
# SIMILAR USERS 5e9eb5ad1cb2e
# SIMILAR USERS 42651
# SIMILAR USERS 190085
# SIMILAR USERS 857383
# SIMILAR USERS 9537
# SIMILAR USERS 10000434
# SIMILAR USERS
# SIMILAR USERS 208885
# SIMILAR USERS 13840
# SIMILAR USERS 10000037
# SIMILAR USERS 114552
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 73735
# SIMILAR USERS 993303
# SIMILAR USERS 281970
# SIMILAR USERS 10000393
# SIMILAR USERS 10000457
# SIMILAR USERS 504493
# SIMILAR USERS 10000078
# SIMILAR USERS 10000033
# SIMILAR USERS 10000232
# SIMILAR USERS 10000297
# SIMILAR USERS 10000331
# SIMILAR USERS 10000352
#
#
# ****************************************************
# User:u1 526964
# SIMILAR USERS 10000282
# SIMILAR USERS 10000416
# SIMILAR USERS 10000389
# SIMILAR USERS 10000367
# SIMILAR USERS 10000390
# SIMILAR USERS 10000417
# SIMILAR USERS 10000413
# SIMILAR USERS 10000218
# SIMILAR USERS 5e984d563502b
# SIMILAR USERS 10000368
# SIMILAR USERS 10000287
# SIMILAR USERS 10000418
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000357
# SIMILAR USERS 10000426
# SIMILAR USERS 10000414
# SIMILAR USERS 5e9de2d595d01
# SIMILAR USERS 5e9debb917b26
# SIMILAR USERS 10000376
# SIMILAR USERS 5e9db436d776b
# SIMILAR USERS 5ea00f958a9c0
# SIMILAR USERS 5ea010b570e44
# SIMILAR USERS 5ea0181600210
# SIMILAR USERS 5ea018da3b305
# SIMILAR USERS 42651
# SIMILAR USERS 190085
# SIMILAR USERS 857383
# SIMILAR USERS 9537
# SIMILAR USERS 10000434
# SIMILAR USERS 208885
# SIMILAR USERS 13840
# SIMILAR USERS 10000037
# SIMILAR USERS 114552
# SIMILAR USERS 10000439
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 73735
# SIMILAR USERS 993303
# SIMILAR USERS 281970
# SIMILAR USERS 10000393
# SIMILAR USERS 10000331
# SIMILAR USERS 10000352
#
#
# ****************************************************
# User:u1 10000364
# SIMILAR USERS 10000430
# SIMILAR USERS 10000286
# SIMILAR USERS 10000440
# SIMILAR USERS 10000364
# SIMILAR USERS 10000446
# SIMILAR USERS 803360
# SIMILAR USERS 603834
#
#
# ****************************************************
# User:u1 252522
#
#
# ****************************************************
# User:u1 121610
#
#
# ****************************************************
# User:u1 73735
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000446
# SIMILAR USERS 10000286
# SIMILAR USERS 10000364
# SIMILAR USERS 10000446
# SIMILAR USERS 803360
# SIMILAR USERS 603834
#
#
# ****************************************************
# User:u1 993303
# SIMILAR USERS 10000367
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
# SIMILAR USERS 993303
#
#
# ****************************************************
# User:u1 10000356
# SIMILAR USERS 10000359
# SIMILAR USERS 10000013
# SIMILAR USERS 10000322
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000099
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 10000360
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000449
# SIMILAR USERS 10000449
#
#
# ****************************************************
# User:u1 357608
#
#
# ****************************************************
# User:u1 38660
#
#
# ****************************************************
# User:u1 282678
#
#
# ****************************************************
# User:u1 150714
#
#
# ****************************************************
# User:u1 281970
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 802690
#
#
# ****************************************************
# User:u1 151021
#
#
# ****************************************************
# User:u1 803360
# SIMILAR USERS 10000430
# SIMILAR USERS 10000286
# SIMILAR USERS 10000440
# SIMILAR USERS 10000364
# SIMILAR USERS 10000446
# SIMILAR USERS 803360
# SIMILAR USERS 603834
#
#
# ****************************************************
# User:u1 171752
#
#
# ****************************************************
# User:u1 10000441
#
#
# ****************************************************
# User:u1 931158
#
#
# ****************************************************
# User:u1 480730
#
#
# ****************************************************
# User:u1 10000393
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000457
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 74454
#
#
# ****************************************************
# User:u1 593618
#
#
# ****************************************************
# User:u1 73619
#
#
# ****************************************************
# User:u1 247642
#
#
# ****************************************************
# User:u1 504493
# SIMILAR USERS 10000357
# SIMILAR USERS 74454
#
#
# ****************************************************
# User:u1 441086
#
#
# ****************************************************
# User:u1 58979
#
#
# ****************************************************
# User:u1 125396
#
#
# ****************************************************
# User:u1 10000458
#
#
# ****************************************************
# User:u1 202679
#
#
# ****************************************************
# User:u1 187741
#
#
# ****************************************************
# User:u1 10000456
#
#
# ****************************************************
# User:u1 10000431
#
#
# ****************************************************
# User:u1 790617
#
#
# ****************************************************
# User:u1 773036
#
#
# ****************************************************
# User:u1 603834
# SIMILAR USERS 10000416
# SIMILAR USERS 10000390
# SIMILAR USERS 10000417
# SIMILAR USERS 10000368
# SIMILAR USERS 10000359
# SIMILAR USERS 10000406
# SIMILAR USERS 10000430
# SIMILAR USERS 10000286
# SIMILAR USERS 10000440
# SIMILAR USERS 10000364
# SIMILAR USERS 10000446
# SIMILAR USERS 803360
# SIMILAR USERS 603834
#
#
# ****************************************************
# User:u1 649483
# SIMILAR USERS 10000000
# SIMILAR USERS 10000368
# SIMILAR USERS 649483
# SIMILAR USERS 10000080
# SIMILAR USERS 10000078
# SIMILAR USERS 842135
# SIMILAR USERS 10000200
# SIMILAR USERS 10000349
#
#
# ****************************************************
# User:u1 597328
# SIMILAR USERS 10000410
# SIMILAR USERS 976794
# SIMILAR USERS 597328
# SIMILAR USERS 10000398
#
#
# ****************************************************
# User:u1 10000459
#
#
# ****************************************************
# User:u1 610577
#
#
# ****************************************************
# User:u1 656219
#
#
# ****************************************************
# User:u1 477656
#
#
# ****************************************************
# User:u1 10000080
# SIMILAR USERS 10000368
# SIMILAR USERS 10000359
# SIMILAR USERS 10000013
# SIMILAR USERS 10000322
# SIMILAR USERS 10000356
# SIMILAR USERS 649483
# SIMILAR USERS 10000080
# SIMILAR USERS 10000099
# SIMILAR USERS 10000078
# SIMILAR USERS 842135
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000349
# SIMILAR USERS 10000297
# SIMILAR USERS 10000360
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000462
#
#
# ****************************************************
# User:u1 10000461
#
#
# ****************************************************
# User:u1 10000187
#
#
# ****************************************************
# User:u1 10000465
#
#
# ****************************************************
# User:u1 10000099
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000104
#
#
# ****************************************************
# User:u1 10000079
#
#
# ****************************************************
# User:u1 10000083
# SIMILAR USERS 10000270
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 10000297
#
#
# ****************************************************
# User:u1 10000106
#
#
# ****************************************************
# User:u1 10000078
# SIMILAR USERS 10000368
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 74454
# SIMILAR USERS 649483
# SIMILAR USERS 10000080
# SIMILAR USERS 842135
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000349
#
#
# ****************************************************
# User:u1 419728
#
#
# ****************************************************
# User:u1 585302
#
#
# ****************************************************
# User:u1 842135
# SIMILAR USERS 10000368
# SIMILAR USERS 649483
# SIMILAR USERS 10000080
# SIMILAR USERS 10000078
# SIMILAR USERS 842135
# SIMILAR USERS 10000200
# SIMILAR USERS 10000349
#
#
# ****************************************************
# User:u1 10000220
#
#
# ****************************************************
# User:u1 10000270
# SIMILAR USERS 10000282
# SIMILAR USERS 10000299
# SIMILAR USERS 10000359
# SIMILAR USERS 10000294
# SIMILAR USERS 10000013
# SIMILAR USERS 10000286
# SIMILAR USERS 10000402
# SIMILAR USERS 10000322
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000099
# SIMILAR USERS 10000083
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 10000360
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 148390
# SIMILAR USERS 10000359
# SIMILAR USERS 10000013
# SIMILAR USERS 10000322
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000099
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 10000360
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 859170
# SIMILAR USERS 10000359
# SIMILAR USERS 10000013
# SIMILAR USERS 10000322
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000099
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 10000360
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000215
#
#
# ****************************************************
# User:u1 597457
#
#
# ****************************************************
# User:u1 10000140
#
#
# ****************************************************
# User:u1 10000033
# SIMILAR USERS 10000357
# SIMILAR USERS 74454
#
#
# ****************************************************
# User:u1 10000288
# SIMILAR USERS 10000282
# SIMILAR USERS 10000299
# SIMILAR USERS 10000367
# SIMILAR USERS 10000359
# SIMILAR USERS 10000294
# SIMILAR USERS 10000289
# SIMILAR USERS 10000013
# SIMILAR USERS 10000286
# SIMILAR USERS 10000402
# SIMILAR USERS 10000322
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000099
# SIMILAR USERS 10000083
# SIMILAR USERS 10000078
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 10000360
# SIMILAR USERS 917319
# SIMILAR USERS 10000340
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000200
# SIMILAR USERS 10000368
# SIMILAR USERS 10000356
# SIMILAR USERS 649483
# SIMILAR USERS 10000080
# SIMILAR USERS 10000078
# SIMILAR USERS 842135
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000349
# SIMILAR USERS 10000297
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 615538
#
#
# ****************************************************
# User:u1 10000227
#
#
# ****************************************************
# User:u1 600564
#
#
# ****************************************************
# User:u1 10000232
# SIMILAR USERS 10000282
# SIMILAR USERS 10000299
# SIMILAR USERS 10000367
# SIMILAR USERS 10000359
# SIMILAR USERS 10000294
# SIMILAR USERS 10000289
# SIMILAR USERS 10000357
# SIMILAR USERS 10000013
# SIMILAR USERS 10000286
# SIMILAR USERS 10000402
# SIMILAR USERS 10000322
# SIMILAR USERS 74454
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000099
# SIMILAR USERS 10000083
# SIMILAR USERS 10000078
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 10000360
# SIMILAR USERS 917319
# SIMILAR USERS 10000340
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000264
#
#
# ****************************************************
# User:u1 10000247
# SIMILAR USERS 10000359
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000099
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 10000360
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000349
# SIMILAR USERS 10000368
# SIMILAR USERS 649483
# SIMILAR USERS 10000080
# SIMILAR USERS 10000078
# SIMILAR USERS 842135
# SIMILAR USERS 10000200
# SIMILAR USERS 10000349
#
#
# ****************************************************
# User:u1 957490
#
#
# ****************************************************
# User:u1 10000261
#
#
# ****************************************************
# User:u1 107973
# SIMILAR USERS 10000294
# SIMILAR USERS 10000289
# SIMILAR USERS 107973
#
#
# ****************************************************
# User:u1 10000138
#
#
# ****************************************************
# User:u1 10000297
# SIMILAR USERS 10000282
# SIMILAR USERS 10000299
# SIMILAR USERS 10000359
# SIMILAR USERS 10000294
# SIMILAR USERS 10000357
# SIMILAR USERS 10000013
# SIMILAR USERS 10000286
# SIMILAR USERS 10000402
# SIMILAR USERS 10000322
# SIMILAR USERS 74454
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000099
# SIMILAR USERS 10000083
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 10000360
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000326
#
#
# ****************************************************
# User:u1 10000360
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000298
#
#
# ****************************************************
# User:u1 917319
# SIMILAR USERS 10000359
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000099
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 10000360
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000279
#
#
# ****************************************************
# User:u1 10000335
#
#
# ****************************************************
# User:u1 10000253
#
#
# ****************************************************
# User:u1 86298
#
#
# ****************************************************
# User:u1 10000331
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000351
#
#
# ****************************************************
# User:u1 10000340
# SIMILAR USERS 10000288
# SIMILAR USERS 10000232
#
#
# ****************************************************
# User:u1 803279
#
#
# ****************************************************
# User:u1 10000352
# SIMILAR USERS 10000357
# SIMILAR USERS 10000414
# SIMILAR USERS 10000376
# SIMILAR USERS 10000037
# SIMILAR USERS 10000410
# SIMILAR USERS 74454
# SIMILAR USERS 526964
#
#
# ****************************************************
# User:u1 10000378
#
#
# ****************************************************
# User:u1 144014
#
#
# ****************************************************
# User:u1 332792
# SIMILAR USERS 10000359
# SIMILAR USERS 10000356
# SIMILAR USERS 10000080
# SIMILAR USERS 10000099
# SIMILAR USERS 10000270
# SIMILAR USERS 148390
# SIMILAR USERS 859170
# SIMILAR USERS 10000288
# SIMILAR USERS 10000200
# SIMILAR USERS 10000232
# SIMILAR USERS 10000247
# SIMILAR USERS 10000297
# SIMILAR USERS 10000360
# SIMILAR USERS 917319
# SIMILAR USERS 332792
#
#
# ****************************************************
# User:u1 10000395
#
#
# ****************************************************
# User:u1 2147483647
#
#
# ****************************************************
# User:u1 10000398
# SIMILAR USERS 10000410
# SIMILAR USERS 976794
# SIMILAR USERS 597328
# SIMILAR USERS 10000398
#
#
# ****************************************************
# User:u1 10000470
#
#
# ****************************************************
# User:u1 10000463
#
#
# ****************************************************
# User:u1 579765

# %%
user_course_map = search_handler.most_common_search(final_user_set)

# %%
for user in user_course_map:
  print("*"*25)
  print("Users similar to {} searched these courses".format(user))
  user_course = user_course_map[user]
  if len(user_course) > 5:
    for i in range(5):
      print("Id: {} Name {}".format(user_course[i],course_details.get(user_course[i].strip(" "),'')))
      # print("Id: {} Name {}".format(user_course[i],course_details[user_course[i].strip(" ")]))
  else:
    for i in range(len(user_course)):
      print("Id: {} Name {}".format(user_course[i],course_details.get(user_course[i].strip(" "),'')))
  print('\n')
# Out:
# *************************
# Users similar to 10000282 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
# Id: 515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000299 searched these courses
# Id: 515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000416 searched these courses
# Id:  777158696144210000417 Name Web Designing with HTML, CSS &amp; Bootstrap
# Id:  257156994522510000218 Name Monthly meetings@CQA
# Id:  340158201405910000218 Name Selenium WebDriver with Java
# Id:  647158704803510000389 Name AI (level 1 )
# Id:  31158437459810000357 Name Bootstrap
#
#
# *************************
# Users similar to 10000389 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000367 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000390 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000000 searched these courses
#
#
# *************************
# Users similar to 10000417 searched these courses
# Id:  375158590506210000302 Name Food Photography
# Id:  179158701107410000416 Name HTML and CSS
# Id:  647158704803510000389 Name AI (level 1 )
# Id:  511158702018510000294 Name Modren Angular Bootcamp (Copy0)
# Id:  515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000413 searched these courses
# Id:  777158696144210000417 Name Web Designing with HTML, CSS &amp; Bootstrap
# Id:  257156994522510000218 Name Monthly meetings@CQA
# Id:  340158201405910000218 Name Selenium WebDriver with Java
# Id:  31158437459810000357 Name Bootstrap
# Id:  470158701696410000420 Name Learn Social Psychology
#
#
# *************************
# Users similar to 10000218 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000420 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 5e984ae3020be searched these courses
#
#
# *************************
# Users similar to 5e984d563502b searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000368 searched these courses
# Id:  647158704803510000389 Name AI (level 1 )
# Id:  586156386555710000099 Name Personality Development and Communication Skill
# Id:  737158711625710000419 Name Photoshop CC 2020
# Id:  447158697470210000419 Name Digital Marketing
# Id:  393158755559210000419 Name Java
#
#
# *************************
# Users similar to 10000287 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000359 searched these courses
# Id: 515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000418 searched these courses
# Id:  375158590506210000302 Name Food Photography
# Id:  179158701107410000416 Name HTML and CSS
# Id:  647158704803510000389 Name AI (level 1 )
# Id:  511158702018510000294 Name Modren Angular Bootcamp (Copy0)
# Id:  515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000294 searched these courses
# Id: 515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 5e9a9dae99aba searched these courses
#
#
# *************************
# Users similar to 5e9aa10f9e498 searched these courses
#
#
# *************************
# Users similar to 10000406 searched these courses
# Id:  375158590506210000302 Name Food Photography
# Id:  179158701107410000416 Name HTML and CSS
# Id:  647158704803510000389 Name AI (level 1 )
# Id:  511158702018510000294 Name Modren Angular Bootcamp (Copy0)
# Id:  515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000430 searched these courses
# Id:  478158634767710000390 Name HTML
# Id:  375158590506210000302 Name Food Photography
# Id:  179158701107410000416 Name HTML and CSS
# Id:  647158704803510000389 Name AI (level 1 )
# Id:  511158702018510000294 Name Modren Angular Bootcamp (Copy0)
#
#
# *************************
# Users similar to 10000289 searched these courses
#
#
# *************************
# Users similar to 10000357 searched these courses
# Id:  349156344060010000081 Name Advance java
# Id:  542156343923610000099 Name Introduction to HTML
# Id:  22156405498210000048 Name Soft Skills
# Id:  43156342626510000080 Name Complete Guitar System
# Id:  375158590506210000302 Name Food Photography
#
#
# *************************
# Users similar to 10000426 searched these courses
# Id:  179158701107410000416 Name HTML and CSS
# Id:  647158704803510000389 Name AI (level 1 )
# Id:  511158702018510000294 Name Modren Angular Bootcamp (Copy0)
# Id:  515156638953610000000 Name Robotics
# Id:  233158547303310000367 Name BIGDATA
#
#
# *************************
# Users similar to 10000414 searched these courses
# Id:  349156344060010000081 Name Advance java
# Id:  542156343923610000099 Name Introduction to HTML
# Id:  22156405498210000048 Name Soft Skills
# Id:  43156342626510000080 Name Complete Guitar System
# Id:  375158590506210000302 Name Food Photography
#
#
# *************************
# Users similar to 5e9d46f21df43 searched these courses
# Id:  777158696144210000417 Name Web Designing with HTML, CSS &amp; Bootstrap
# Id:  257156994522510000218 Name Monthly meetings@CQA
# Id:  647158704803510000389 Name AI (level 1 )
# Id:  31158437459810000357 Name Bootstrap
# Id:  470158701696410000420 Name Learn Social Psychology
#
#
# *************************
# Users similar to 10000013 searched these courses
# Id: 515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000286 searched these courses
# Id:  152158832503910000406 Name Cyber Security
# Id: 515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000302 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 5e9db8b35aee1 searched these courses
# Id:  586156386555710000099 Name Personality Development and Communication Skill
# Id:  170156784201510000081 Name Online Yoga
# Id:  462158667172110000302 Name Complete Wordpress Theme Development Course
# Id:  837158600584110000081 Name xml 4
# Id:  737158711625710000419 Name Photoshop CC 2020
#
#
# *************************
# Users similar to 5e9dbe157cae6 searched these courses
#
#
# *************************
# Users similar to 5e9de2d595d01 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000081 searched these courses
#
#
# *************************
# Users similar to 5e9debb917b26 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000376 searched these courses
# Id:  349156344060010000081 Name Advance java
# Id:  542156343923610000099 Name Introduction to HTML
# Id:  22156405498210000048 Name Soft Skills
# Id:  43156342626510000080 Name Complete Guitar System
# Id:  375158590506210000302 Name Food Photography
#
#
# *************************
# Users similar to 5e9db436d776b searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 5e9f3134c740a searched these courses
# Id:  737158711625710000419 Name Photoshop CC 2020
# Id:  233158547303310000367 Name BIGDATA
# Id:  771158583266210000368 Name cooking
# Id:  287158858757010000368 Name
# Id:  295158601606210000302 Name Paint Realistic Watercolor (Copy0)
#
#
# *************************
# Users similar to 5ea00f958a9c0 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 5ea010b570e44 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 5ea0181600210 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 5ea018da3b305 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 5ea02ee9bc9f3 searched these courses
#
#
# *************************
# Users similar to 5e9eb5ad1cb2e searched these courses
#
#
# *************************
# Users similar to 42651 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 190085 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 857383 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 9537 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000434 searched these courses
# Id:  375158590506210000302 Name Food Photography
# Id:  179158701107410000416 Name HTML and CSS
# Id:  647158704803510000389 Name AI (level 1 )
# Id:  515156638953610000000 Name Robotics
# Id:  233158547303310000367 Name BIGDATA
#
#
# *************************
# Users similar to  searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
#
#
# *************************
# Users similar to 10000402 searched these courses
# Id: 515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 208885 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 13840 searched these courses
# Id:  777158696144210000417 Name Web Designing with HTML, CSS &amp; Bootstrap
# Id:  31158437459810000357 Name Bootstrap
# Id:  470158701696410000420 Name Learn Social Psychology
# Id:  295158601606210000302 Name Paint Realistic Watercolor (Copy0)
# Id:  656158731510310000417 Name Photo Editing Masterclass using Adobe
#
#
# *************************
# Users similar to 10000037 searched these courses
# Id:  43156342626510000080 Name Complete Guitar System
# Id:  375158590506210000302 Name Food Photography
# Id:  367157961776610000282 Name Blockchain
# Id:  759158666877610000390 Name Interior Designs
# Id:  515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000440 searched these courses
#
#
# *************************
# Users similar to 114552 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  241158738114310000420 Name Complete Design Thinking
# Id:  608158782373810000420 Name The Complete SQL Bootcamp 2020
#
#
# *************************
# Users similar to 10000439 searched these courses
# Id:  375158590506210000302 Name Food Photography
# Id:  179158701107410000416 Name HTML and CSS
# Id:  647158704803510000389 Name AI (level 1 )
# Id:  511158702018510000294 Name Modren Angular Bootcamp (Copy0)
# Id:  515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000410 searched these courses
# Id:  43156342626510000080 Name Complete Guitar System
# Id:  375158590506210000302 Name Food Photography
# Id:  367157961776610000282 Name Blockchain
# Id:  759158666877610000390 Name Interior Designs
# Id:  515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 976794 searched these courses
#
#
# *************************
# Users similar to 10000322 searched these courses
# Id:  257156994522510000218 Name Monthly meetings@CQA
# Id:  263158306687310000282 Name The Ultimate Drawing Masterclass
# Id: 515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 74454 searched these courses
# Id:  349156344060010000081 Name Advance java
# Id:  542156343923610000099 Name Introduction to HTML
# Id:  22156405498210000048 Name Soft Skills
# Id:  43156342626510000080 Name Complete Guitar System
# Id:  375158590506210000302 Name Food Photography
#
#
# *************************
# Users similar to 526964 searched these courses
# Id:  43156342626510000080 Name Complete Guitar System
# Id:  375158590506210000302 Name Food Photography
# Id:  367157961776610000282 Name Blockchain
# Id:  759158666877610000390 Name Interior Designs
# Id:  515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000364 searched these courses
# Id:  919158696284310000418 Name AUTOMATION ANYWHERE
# Id:  152158832503910000406 Name Cyber Security
# Id:  386158869513610000440 Name
# Id:  898158789403710000419 Name python
# Id:  393158755559210000419 Name Java
#
#
# *************************
# Users similar to 73735 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000446 searched these courses
# Id:  152158832503910000406 Name Cyber Security
#
#
# *************************
# Users similar to 993303 searched these courses
# Id:  737158711625710000419 Name Photoshop CC 2020
# Id:  771158583266210000368 Name cooking
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
#
#
# *************************
# Users similar to 10000356 searched these courses
# Id:  31158437459810000357 Name Bootstrap
# Id:  233158547303310000367 Name BIGDATA
# Id:  740158737126310000389 Name Data Science
# Id:  737158711625710000419 Name Photoshop CC 2020
# Id:  374158781517410000359 Name Learn flutter from scratch
#
#
# *************************
# Users similar to 10000449 searched these courses
#
#
# *************************
# Users similar to 281970 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 803360 searched these courses
# Id:  919158696284310000418 Name AUTOMATION ANYWHERE
# Id:  152158832503910000406 Name Cyber Security
# Id:  386158869513610000440 Name
# Id: 891158895044810000406 Name
# Id:  898158789403710000419 Name python
#
#
# *************************
# Users similar to 10000393 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000457 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 504493 searched these courses
#
#
# *************************
# Users similar to 603834 searched these courses
# Id:  478158634767710000390 Name HTML
# Id:  949158609709610000390 Name Web Designing for Beginners
# Id:  179158701107410000416 Name HTML and CSS
# Id:  647158704803510000389 Name AI (level 1 )
# Id:  515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 649483 searched these courses
# Id:  586156386555710000099 Name Personality Development and Communication Skill
# Id:  170156784201510000081 Name Online Yoga
# Id:  462158667172110000302 Name Complete Wordpress Theme Development Course
# Id:  233158547303310000367 Name BIGDATA
# Id:  837158600584110000081 Name xml 4
#
#
# *************************
# Users similar to 597328 searched these courses
#
#
# *************************
# Users similar to 10000080 searched these courses
# Id:  771158583266210000368 Name cooking
# Id:  737158711625710000419 Name Photoshop CC 2020
# Id:  740158737126310000389 Name Data Science
# Id:  393158755559210000419 Name Java
# Id:  919158696284310000418 Name AUTOMATION ANYWHERE
#
#
# *************************
# Users similar to 10000099 searched these courses
# Id: 515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000083 searched these courses
# Id: 515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000078 searched these courses
# Id:  393158755559210000419 Name Java
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id:  457158782807710000390 Name Solar Energy
# Id:  287158858757010000368 Name
# Id:  210158886389110000390 Name
#
#
# *************************
# Users similar to 842135 searched these courses
# Id:  393158755559210000419 Name Java
# Id:  457158782807710000390 Name Solar Energy
# Id:  287158858757010000368 Name
# Id:  210158886389110000390 Name
# Id: 170156784201510000081 Name Online Yoga
#
#
# *************************
# Users similar to 10000270 searched these courses
# Id:  676156155235810000000 Name Learn Ethical Hacking From Scratch
# Id:  43156342626510000080 Name Complete Guitar System
# Id:  367157961776610000282 Name Blockchain
# Id:  381158589141810000302 Name Paint Realistic Watercolor
# Id:  512158696428910000282 Name The Art of Energy Healing
#
#
# *************************
# Users similar to 148390 searched these courses
# Id:  31158437459810000357 Name Bootstrap
# Id:  233158547303310000367 Name BIGDATA
# Id:  740158737126310000389 Name Data Science
# Id:  737158711625710000419 Name Photoshop CC 2020
# Id:  374158781517410000359 Name Learn flutter from scratch
#
#
# *************************
# Users similar to 859170 searched these courses
# Id:  31158437459810000357 Name Bootstrap
# Id:  233158547303310000367 Name BIGDATA
# Id:  740158737126310000389 Name Data Science
# Id:  737158711625710000419 Name Photoshop CC 2020
# Id:  374158781517410000359 Name Learn flutter from scratch
#
#
# *************************
# Users similar to 10000033 searched these courses
#
#
# *************************
# Users similar to 10000288 searched these courses
# Id:  676156155235810000000 Name Learn Ethical Hacking From Scratch
# Id:  43156342626510000080 Name Complete Guitar System
# Id:  367157961776610000282 Name Blockchain
# Id:  381158589141810000302 Name Paint Realistic Watercolor
# Id:  515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000200 searched these courses
# Id:  393158755559210000419 Name Java
# Id:  457158782807710000390 Name Solar Energy
# Id:  287158858757010000368 Name
# Id:  210158886389110000390 Name
# Id: 170156784201510000081 Name Online Yoga
#
#
# *************************
# Users similar to 10000232 searched these courses
# Id:  676156155235810000000 Name Learn Ethical Hacking From Scratch
# Id:  43156342626510000080 Name Complete Guitar System
# Id:  367157961776610000282 Name Blockchain
# Id:  381158589141810000302 Name Paint Realistic Watercolor
# Id:  515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 10000247 searched these courses
# Id:  31158437459810000357 Name Bootstrap
# Id:  233158547303310000367 Name BIGDATA
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id:  254158738215210000294 Name Advanced Data Structures (Copy0)
# Id:  322157599163910000013 Name Robotic Process Automation
#
#
# *************************
# Users similar to 10000349 searched these courses
# Id:  393158755559210000419 Name Java
# Id:  457158782807710000390 Name Solar Energy
# Id:  287158858757010000368 Name
# Id:  210158886389110000390 Name
# Id: 170156784201510000081 Name Online Yoga
#
#
# *************************
# Users similar to 107973 searched these courses
#
#
# *************************
# Users similar to 10000297 searched these courses
# Id:  676156155235810000000 Name Learn Ethical Hacking From Scratch
# Id:  43156342626510000080 Name Complete Guitar System
# Id:  367157961776610000282 Name Blockchain
# Id:  381158589141810000302 Name Paint Realistic Watercolor
# Id:  512158696428910000282 Name The Art of Energy Healing
#
#
# *************************
# Users similar to 10000360 searched these courses
# Id: 515156638953610000000 Name Robotics
#
#
# *************************
# Users similar to 917319 searched these courses
# Id:  31158437459810000357 Name Bootstrap
# Id:  233158547303310000367 Name BIGDATA
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id:  254158738215210000294 Name Advanced Data Structures (Copy0)
# Id:  322157599163910000013 Name Robotic Process Automation
#
#
# *************************
# Users similar to 10000331 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 10000340 searched these courses
#
#
# *************************
# Users similar to 10000352 searched these courses
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id: 374158781517410000359 Name Learn flutter from scratch
# Id:  767158721964010000414 Name Jewellery Designing
# Id:  226158859222410000420 Name
#
#
# *************************
# Users similar to 332792 searched these courses
# Id:  31158437459810000357 Name Bootstrap
# Id:  233158547303310000367 Name BIGDATA
# Id:  374158781517410000359 Name Learn flutter from scratch
# Id:  254158738215210000294 Name Advanced Data Structures (Copy0)
# Id:  322157599163910000013 Name Robotic Process Automation
#
#
# *************************
# Users similar to 10000398 searched these courses
